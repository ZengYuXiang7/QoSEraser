# %% [markdown]
# # Author : Yuxiang Zeng

# %% [markdown]
# # 命令制作

# %%
# 消融实验 分片
for slices in [10, 15, 20]:
    for density in ['0.20']:
        for dataset in ['rt', 'tp']:
            for interaction in ['NeuCF', 'CSMF', 'MF', 'GraphMF']:
                string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 1 --slices {slices} --agg_epochs 60 --density {density} --part_type 5 '
                string += f'--slices {slices} --record 0'
                string += ' --ex Ablation'
                print(string)
                print('#%%')
# Out:
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation
# #%%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation
# #%%
# !python Experiment.py --dataset rt --interaction MF --rounds 1 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation
# #%%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation
# #%%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation
# #%%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation
# ...

# %%
# 消融实验 分片
for slices in [10, 15, 20]:
    for density in ['0.20']:
        for dataset in ['rt', 'tp']:
            for interaction in ['NeuCF', 'CSMF', 'MF', 'GraphMF']:
                if interaction in ['NeuCF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {12 if dataset == "rt" else 15} --density {density} --part_type 5 '
                elif interaction in ['CSMF', 'MF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {25 if dataset == "rt" else 30} --density {density} --part_type 5 '
                else:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs 50 --density {density} --part_type 5 '
                string += f'--slices {slices} --record 0'
                string += ' --ex Ablation'
                print(string)
                print('#%%')

# 消融实验 聚合方式
for agg_type in ['mean', 'softmax', 'att2']:
    for density in ['0.20']:
        for dataset in ['rt', 'tp']:
            for interaction in ['NeuCF', 'CSMF', 'MF', 'GraphMF']:
                if interaction in ['NeuCF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {12 if dataset == "rt" else 15} --density {density} --part_type 5 '
                elif interaction in ['CSMF', 'MF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {25 if dataset == "rt" else 30} --density {density} --part_type 5 '
                else:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs 50 --density {density} --part_type 5 '
                string += f'--agg_type {agg_type} --record 0'
                string += ' --ex Ablation'
                print(string)
                print('#%%')

# 消融实验 切割方式
for part_type in [2, 6, 8]:
    for density in ['0.20']:
        for dataset in ['rt', 'tp']:
            for interaction in ['NeuCF', 'CSMF', 'MF', 'GraphMF']:
                if interaction in ['NeuCF', 'GraphMF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {12 if dataset == "rt" else 15} --density {density} --part_type {part_type} '
                elif interaction in ['CSMF', 'MF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {25 if dataset == "rt" else 30} --density {density} --part_type {part_type} '
                else:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs 50 --density {density} --part_type {part_type} '
                string += f'--record 0'
                string += ' --ex Ablation'
                print(string)
                print('#%%')
# Out:
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation
# #%%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 5 --slices 5 --agg_epochs 25 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation
# #%%
# !python Experiment.py --dataset rt --interaction MF --rounds 5 --slices 5 --agg_epochs 25 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation
# #%%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation
# #%%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation
# #%%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 5 --slices 5 --agg_epochs 30 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation
# #%%
# ...

# %%
# NCF 确定！！！！！！！！！！！！！！！！！！！！！！
for interaction in ['NeuCF']:
    for dataset in ['rt', 'tp']:
        for density in ['0.10', '0.15', '0.20', '0.25', '0.30']:
            for part_type in [5]:
                string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {12 if dataset == "rt" else 15} --density {density} --part_type {part_type} '
                string += '--ex performance'
                print(string)
                print('#%%')
# CSMF
for interaction in ['CSMF']:
    for dataset in ['rt', 'tp']:
        for density in ['0.10', '0.15', '0.20', '0.25', '0.30']:
            for part_type in [5]:
                string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {25 if dataset == "rt" else 30} --density {density} --part_type {part_type} '
                string += '--ex performance'
                print(string)
                print('#%%')
                # MF
for interaction in ['MF']:
    for dataset in ['rt', 'tp']:
        for density in ['0.10', '0.15', '0.20', '0.25', '0.30']:
            for part_type in [5]:
                string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {25 if dataset == "rt" else 30} --density {density} --part_type {part_type} '
                string += '--ex performance'
                print(string)
                print('#%%')
                # MFR

for interaction in ['GraphMF']:
    for dataset in ['rt', 'tp']:
        for density in ['0.10', '0.15', '0.20', '0.25', '0.30']:
            for part_type in [5]:
                string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs 50 --density {density} --part_type {part_type} '
                string += '--ex performance'
                print(string)
                print('#%%')

# Baselines
for interaction in ['NeuCF', 'CSMF', 'MF', 'GraphMF']:
    for dataset in ['rt', 'tp']:
        for density in ['0.10', '0.15', '0.20', '0.25', '0.30']:
            for part_type in [1, 3]:
                if interaction in ['NeuCF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {12 if dataset == "rt" else 15} --density {density} --part_type {part_type} '
                elif interaction in ['CSMF', 'MF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {25 if dataset == "rt" else 30} --density {density} --part_type {part_type} '
                else:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs 50 --density {density} --part_type {part_type} '
                string += '--ex performance'
                print(string)
                print('#%%')

# 消融实验 分片
for slices in [10, 15, 20]:
    for density in ['0.20']:
        for dataset in ['rt', 'tp']:
            for interaction in ['NeuCF', 'CSMF', 'MF', 'GraphMF']:
                if interaction in ['NeuCF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {12 if dataset == "rt" else 15} --density {density} --part_type 5 '
                elif interaction in ['CSMF', 'MF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {25 if dataset == "rt" else 30} --density {density} --part_type 5 '
                else:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs 50 --density {density} --part_type 5 '
                string += f'--slices {slices} --record 0'
                string += ' --ex Ablation'
                print(string)
                print('#%%')

# 消融实验 聚合方式
for agg_type in ['mean', 'softmax']:
    for density in ['0.20']:
        for dataset in ['rt', 'tp']:
            for interaction in ['NeuCF', 'CSMF', 'MF', 'GraphMF']:
                if interaction in ['NeuCF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {12 if dataset == "rt" else 15} --density {density} --part_type 5 '
                elif interaction in ['CSMF', 'MF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {25 if dataset == "rt" else 30} --density {density} --part_type 5 '
                else:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs 50 --density {density} --part_type 5 '
                string += f'--agg_type {agg_type} --record 0'
                string += ' --ex Ablation'
                print(string)
                print('#%%')

# 消融实验 切割方式
for part_type in [6, 8]:
    for density in ['0.20']:
        for dataset in ['rt', 'tp']:
            for interaction in ['NeuCF', 'CSMF', 'MF', 'GraphMF']:
                if interaction in ['NeuCF', 'GraphMF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {12 if dataset == "rt" else 15} --density {density} --part_type {part_type} '
                elif interaction in ['CSMF', 'MF']:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs {25 if dataset == "rt" else 30} --density {density} --part_type {part_type} '
                else:
                    string = f'!python Experiment.py --dataset {dataset} --interaction {interaction} --rounds 5 --slices 5 --agg_epochs 50 --density {density} --part_type {part_type} '
                string += f'--record 0'
                string += ' --ex Ablation'
                print(string)
                print('#%%')

for interaction in ['NeuCF', 'CSMF', 'MF', 'GraphMF']:
    for dataset in ['rt', 'tp']:
        for density in ['0.10', '0.15', '0.20', '0.25', '0.30']:
            string = f'!python Retrain.py --dataset {dataset} --interaction {interaction} --rounds 5 --density {density} --part_type 10 '
            string += '--ex Retrain'
            print(string)
            print('#%%')
# Out:
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.10 --part_type 5 --ex performance
# #%%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.15 --part_type 5 --ex performance
# #%%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --ex performance
# #%%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.25 --part_type 5 --ex performance
# #%%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.30 --part_type 5 --ex performance
# #%%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 15 --density 0.10 --part_type 5 --ex performance
# #%%
# ...
