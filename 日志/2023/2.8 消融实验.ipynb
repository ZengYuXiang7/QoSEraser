# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --slices 10 --record 0
# Out:
# 2023-02-08 12:58:58  Experiment start!
# 2023-02-08 12:58:58  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=12, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, record=0, retrain=0, rounds=5, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --slices 10 --record 0

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 5 --slices 5 --agg_epochs 25 --density 0.20 --part_type 5 --slices 10 --record 0

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --slices 10 --record 0

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --slices 10 --record 0

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 5 --slices 5 --agg_epochs 20 --density 0.20 --part_type 5 --slices 10 --record 0

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 5 --slices 5 --agg_epochs 30 --density 0.20 --part_type 5 --slices 10 --record 0

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --slices 10 --record 0

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --slices 15 --record 0

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --slices 15 --record 0

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 5 --slices 5 --agg_epochs 25 --density 0.20 --part_type 5 --slices 15 --record 0

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --slices 15 --record 0

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --slices 15 --record 0

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 5 --slices 5 --agg_epochs 20 --density 0.20 --part_type 5 --slices 15 --record 0

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 5 --slices 5 --agg_epochs 30 --density 0.20 --part_type 5 --slices 15 --record 0

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --slices 15 --record 0

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --slices 20 --record 0

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --slices 20 --record 0

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 5 --slices 5 --agg_epochs 25 --density 0.20 --part_type 5 --slices 20 --record 0

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --slices 20 --record 0

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --slices 20 --record 0

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 5 --slices 5 --agg_epochs 20 --density 0.20 --part_type 5 --slices 20 --record 0

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 5 --slices 5 --agg_epochs 30 --density 0.20 --part_type 5 --slices 20 --record 0

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --slices 20 --record 0

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --agg_type mean --record 0

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --agg_type mean --record 0

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 5 --slices 5 --agg_epochs 25 --density 0.20 --part_type 5 --agg_type mean --record 0

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --agg_type mean --record 0

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --agg_type mean --record 0

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 5 --slices 5 --agg_epochs 20 --density 0.20 --part_type 5 --agg_type mean --record 0

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 5 --slices 5 --agg_epochs 30 --density 0.20 --part_type 5 --agg_type mean --record 0

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --agg_type mean --record 0

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --agg_type softmax --record 0

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --agg_type softmax --record 0

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 5 --slices 5 --agg_epochs 25 --density 0.20 --part_type 5 --agg_type softmax --record 0

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --agg_type softmax --record 0

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --agg_type softmax --record 0

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 5 --slices 5 --agg_epochs 20 --density 0.20 --part_type 5 --agg_type softmax --record 0

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 5 --slices 5 --agg_epochs 30 --density 0.20 --part_type 5 --agg_type softmax --record 0

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --agg_type softmax --record 0

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 6 --record 0

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 6 --record 0

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 5 --slices 5 --agg_epochs 25 --density 0.20 --part_type 6 --record 0

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 6 --record 0

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 6 --record 0

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 5 --slices 5 --agg_epochs 20 --density 0.20 --part_type 6 --record 0

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 5 --slices 5 --agg_epochs 30 --density 0.20 --part_type 6 --record 0

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 6 --record 0

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 8 --record 0
# Out:
# 2023-02-08 13:00:55  Experiment start!
# 2023-02-08 13:00:55  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=12, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=8, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, record=0, retrain=0, rounds=5, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 8 --record 0

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 5 --slices 5 --agg_epochs 25 --density 0.20 --part_type 8 --record 0
# Out:
# 2023-02-08 13:03:28  Experiment start!
# 2023-02-08 13:03:28  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=25, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=8, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, record=0, retrain=0, rounds=5, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 12 --density 0.20 --part_type 8 --record 0
# Out:
# 2023-02-08 13:30:48  Experiment start!
# 2023-02-08 13:30:48  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=12, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=8, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, record=0, retrain=0, rounds=5, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 8 --record 0
# Out:
# 2023-02-08 13:48:32  Experiment start!
# 2023-02-08 13:48:32  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=8, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, record=0, retrain=0, rounds=5, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 5 --slices 5 --agg_epochs 20 --density 0.20 --part_type 8 --record 0
# Out:
# 2023-02-08 14:27:05  Experiment start!
# 2023-02-08 14:27:05  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=20, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=8, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, record=0, retrain=0, rounds=5, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 5 --slices 5 --agg_epochs 30 --density 0.20 --part_type 8 --record 0
# Out:
# 2023-02-08 14:58:01  Experiment start!
# 2023-02-08 14:58:01  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=30, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=8, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, record=0, retrain=0, rounds=5, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 5 --slices 5 --agg_epochs 15 --density 0.20 --part_type 8 --record 0
# Out:
# 2023-02-08 15:29:26  Experiment start!
# 2023-02-08 15:29:26  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=8, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, record=0, retrain=0, rounds=5, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...
