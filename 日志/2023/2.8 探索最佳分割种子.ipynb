# %% [markdown]
# # Our

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.10 --part_type 5 --random_state 2022 --record 0
# Out:
# python: can't open file 'Experiment.py': [Errno 2] No such file or directory

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.15 --part_type 5 --random_state 2022 --record 0
# Out:
# 2023-02-10 22:52:24  Experiment start!
# 2023-02-10 22:52:24  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.15, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --random_state 2022 --record 0
# Out:
# 2023-02-10 22:55:29  Experiment start!
# 2023-02-10 22:55:29  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.25 --part_type 5 --random_state 2022 --record 0
# Out:
# 2023-02-10 22:58:57  Experiment start!
# 2023-02-10 22:58:57  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.25, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.30 --part_type 5 --random_state 2022 --record 0
# Out:
# 2023-02-10 23:02:47  Experiment start!
# 2023-02-10 23:02:47  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.3, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %% [markdown]
# *****

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.10 --part_type 1 --random_state 2022 --record 0
# Out:
# 2023-02-10 23:06:55  Experiment start!
# 2023-02-10 23:06:55  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=1, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.15 --part_type 1 --random_state 2022 --record 0
# Out:
# 2023-02-10 23:09:14  Experiment start!
# 2023-02-10 23:09:14  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.15, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=1, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.20 --part_type 1 --random_state 2022 --record 0
# Out:
# 2023-02-10 23:11:35  Experiment start!
# 2023-02-10 23:11:35  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=1, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.25 --part_type 1 --random_state 2022 --record 0
# Out:
# 2023-02-10 23:13:57  Experiment start!
# 2023-02-10 23:13:57  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.25, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=1, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.30 --part_type 1 --random_state 2022 --record 0
# Out:
# 2023-02-10 23:31:54  Experiment start!
# 2023-02-10 23:31:54  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.3, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=1, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=10, wd=0.0005)
# ...

# %% [markdown]
# *****
