# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 128
# Out:
# 2023-01-28 01:31:28  Experiment start!
# 2023-01-28 01:31:28  Namespace(agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=128, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-28 01:31:28  Dataset : rt     interaction : NeuCF
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 64
# Out:
# 2023-01-28 01:34:36  Experiment start!
# 2023-01-28 01:34:36  Namespace(agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-28 01:34:36  Dataset : rt     interaction : NeuCF
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 32
# Out:
# 2023-01-28 01:37:33  Experiment start!
# 2023-01-28 01:37:33  Namespace(agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=32, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-28 01:37:33  Dataset : rt     interaction : NeuCF
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 512
# Out:
# 2023-01-28 02:15:15  Experiment start!
# 2023-01-28 02:15:15  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=512, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:15:15  Dataset : rt     interaction : CSMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 256
# Out:
# 2023-01-28 01:49:00  Experiment start!
# 2023-01-28 01:49:00  Namespace(agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=256, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-28 01:49:00  Dataset : rt     interaction : CSMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --agg_epochs 15 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 128
# Out:
# 2023-01-28 02:27:01  Experiment start!
# 2023-01-28 02:27:01  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=128, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:27:01  Dataset : rt     interaction : CSMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --agg_epochs 15 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 32
# Out:
# 2023-01-28 01:42:45  Experiment start!
# 2023-01-28 01:42:45  Namespace(agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-28 01:42:45  Dataset : rt     interaction : CSMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --agg_epochs 20 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 32
# Out:
# 2023-01-28 02:32:14  Experiment start!
# 2023-01-28 02:32:14  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=20, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=32, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:32:14  Dataset : rt     interaction : CSMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --agg_epochs 15 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 64
# Out:
# 2023-01-28 02:35:28  Experiment start!
# 2023-01-28 02:35:28  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:35:28  Dataset : rt     interaction : GraphMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --agg_epochs 15 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 32
# Out:
# 2023-01-28 02:37:34  Experiment start!
# 2023-01-28 02:37:34  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=32, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:37:34  Dataset : rt     interaction : GraphMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --agg_epochs 15 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 16
# Out:
# 2023-01-28 02:42:05  Experiment start!
# 2023-01-28 02:42:05  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=16, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:42:05  Dataset : rt     interaction : GraphMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --agg_epochs 15 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 64
# Out:
# 2023-01-28 02:44:15  Experiment start!
# 2023-01-28 02:44:15  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:44:15  Dataset : rt     interaction : GraphMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --agg_epochs 15 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 16
# Out:
# 2023-01-28 02:20:22  Experiment start!
# 2023-01-28 02:20:22  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=16, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:20:22  Dataset : rt     interaction : CSMF
# ...

# %%
# Out:
# 2023-01-28 02:11:05  Experiment start!
# 2023-01-28 02:11:05  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=256, hidden_dims=[64, 64, 100], input_dim=128, interaction='Pure_Mf', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:11:05  Dataset : rt     interaction : Pure_Mf
# ...

# %%
# !python Experiment.py --dataset rt --interaction Pure_Mf --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 512
# Out:
# 2023-01-28 02:09:46  Experiment start!
# 2023-01-28 02:09:46  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=512, hidden_dims=[64, 64, 100], input_dim=128, interaction='Pure_Mf', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:09:46  Dataset : rt     interaction : Pure_Mf
# ...

# %%
# !python Experiment.py --dataset rt --interaction Pure_Mf --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 64
# Out:
# 2023-01-28 01:54:56  Experiment start!
# 2023-01-28 01:54:56  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='Pure_Mf', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 01:54:56  Dataset : rt     interaction : Pure_Mf
# ...

# %%
# !python Experiment.py --dataset rt --interaction Pure_Mf --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 128
# Out:
# 2023-01-28 02:03:20  Experiment start!
# 2023-01-28 02:03:20  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=128, hidden_dims=[64, 64, 100], input_dim=128, interaction='Pure_Mf', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:03:20  Dataset : rt     interaction : Pure_Mf
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 256
# Out:
# 2023-01-28 02:04:43  Experiment start!
# 2023-01-28 02:04:43  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=256, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:04:43  Dataset : rt     interaction : GraphMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 512
# Out:
# 2023-01-28 02:07:43  Experiment start!
# 2023-01-28 02:07:43  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=512, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:07:43  Dataset : rt     interaction : GraphMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction Pure_Mf --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 32
# Out:
# 2023-01-28 01:56:16  Experiment start!
# 2023-01-28 01:56:16  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=32, hidden_dims=[64, 64, 100], input_dim=128, interaction='Pure_Mf', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 01:56:16  Dataset : rt     interaction : Pure_Mf
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 128
# Out:
# 2023-01-28 01:57:30  Experiment start!
# 2023-01-28 01:57:30  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=128, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 01:57:30  Dataset : rt     interaction : GraphMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --agg_epochs 15 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 64
# Out:
# 2023-01-28 01:59:28  Experiment start!
# 2023-01-28 01:59:28  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 01:59:28  Dataset : rt     interaction : GraphMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 32
# Out:
# 2023-01-28 02:01:24  Experiment start!
# 2023-01-28 02:01:24  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=32, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:01:24  Dataset : rt     interaction : GraphMF
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --agg_type att --debug 1 --external_dim 16
# Out:
# 2023-01-28 02:18:01  Experiment start!
# 2023-01-28 02:18:01  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, external_dim=16, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=10, verbose=10, wd=0.0005)
# 2023-01-28 02:18:01  Dataset : rt     interaction : GraphMF
# ...
