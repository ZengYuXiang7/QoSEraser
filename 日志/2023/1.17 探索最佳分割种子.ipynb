# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 5 --density 0.10 --part_type 5 --debug 1 --cluster kmean --random_state 1000
# Out:
# 2023-01-17 17:56:58  Namespace(agg2=1, agg_epochs=5, agg_function=1, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='kmean', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1000, retrain=0, rounds=1, save_model=1, slice_epochs=60, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-17 17:56:58  Experiment start!
# 2023-01-17 17:56:58  Dataset : rt     interaction : NeuCF
# 2023-01-17 17:56:58  Density : 10.00%, slice_epochs : 100, agg_epochs : 5
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 5 --density 0.10 --part_type 5 --debug 1 --cluster kmean --random_state 1001
# Out:
# 2023-01-17 18:04:23  Namespace(agg2=1, agg_epochs=5, agg_function=1, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='kmean', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice_epochs=60, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-17 18:04:23  Experiment start!
# 2023-01-17 18:04:23  Dataset : rt     interaction : NeuCF
# 2023-01-17 18:04:23  Density : 10.00%, slice_epochs : 100, agg_epochs : 5
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 5 --density 0.10 --part_type 5 --debug 1 --cluster kmean --random_state 1002
# Out:
# 2023-01-17 18:11:53  Namespace(agg2=1, agg_epochs=5, agg_function=1, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='kmean', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1002, retrain=0, rounds=1, save_model=1, slice_epochs=60, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-17 18:11:53  Experiment start!
# 2023-01-17 18:11:53  Dataset : rt     interaction : NeuCF
# 2023-01-17 18:11:53  Density : 10.00%, slice_epochs : 100, agg_epochs : 5
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 5 --density 0.10 --part_type 5 --debug 1 --cluster kmean --random_state 1003
# Out:
# 2023-01-17 18:18:57  Namespace(agg2=1, agg_epochs=5, agg_function=1, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='kmean', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1003, retrain=0, rounds=1, save_model=1, slice_epochs=60, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-17 18:18:57  Experiment start!
# 2023-01-17 18:18:57  Dataset : rt     interaction : NeuCF
# 2023-01-17 18:18:57  Density : 10.00%, slice_epochs : 100, agg_epochs : 5
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 5 --density 0.10 --part_type 5 --debug 1 --cluster kmean --random_state 1004
# Out:
# 2023-01-17 18:25:53  Namespace(agg2=1, agg_epochs=5, agg_function=1, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='kmean', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1004, retrain=0, rounds=1, save_model=1, slice_epochs=60, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-17 18:25:53  Experiment start!
# 2023-01-17 18:25:53  Dataset : rt     interaction : NeuCF
# 2023-01-17 18:25:53  Density : 10.00%, slice_epochs : 100, agg_epochs : 5
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 5 --density 0.10 --part_type 5 --debug 1 --cluster kmean --random_state 1005
# Out:
# 2023-01-17 18:32:46  Namespace(agg2=1, agg_epochs=5, agg_function=1, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='kmean', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1005, retrain=0, rounds=1, save_model=1, slice_epochs=60, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-17 18:32:46  Experiment start!
# 2023-01-17 18:32:46  Dataset : rt     interaction : NeuCF
# 2023-01-17 18:32:46  Density : 10.00%, slice_epochs : 100, agg_epochs : 5
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 5 --density 0.10 --part_type 5 --debug 1 --cluster kmean --random_state 1006
# Out:
# 2023-01-17 18:39:44  Namespace(agg2=1, agg_epochs=5, agg_function=1, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='kmean', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1006, retrain=0, rounds=1, save_model=1, slice_epochs=60, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-17 18:39:44  Experiment start!
# 2023-01-17 18:39:44  Dataset : rt     interaction : NeuCF
# 2023-01-17 18:39:44  Density : 10.00%, slice_epochs : 100, agg_epochs : 5
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 5 --density 0.10 --part_type 5 --debug 1 --cluster kmean --random_state 2024
