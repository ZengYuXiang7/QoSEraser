# %% [markdown]
# # Author: Yuxiang Zeng

# %% [markdown]
# # Method : Ours    Idea新尝试

# %% [markdown]
# ## Dataset : rt

# %% [markdown]
# # Desity = 0.10

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --dimension 64 --rounds 1 --slice_epochs 100 --agg_epochs 5 --density 0.10 --part_type 5 --debug 1 --agg_function 2
# Out:
# 2023-01-18 03:52:42  Namespace(agg2=1, agg_epochs=5, agg_function=2, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice_epochs=100, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-18 03:52:42  Experiment start!
# 2023-01-18 03:52:42  Dataset : rt     interaction : NeuCF
# 2023-01-18 03:52:42  Density : 10.00%, slice_epochs : 100, agg_epochs : 5
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 60 --agg_epochs 10 --density 0.10 --part_type 5 --debug 1 --agg_function 2
# Out:
# 2023-01-18 04:01:18  Namespace(agg2=1, agg_epochs=10, agg_function=2, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice_epochs=60, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-18 04:01:18  Experiment start!
# 2023-01-18 04:01:18  Dataset : rt     interaction : CSMF
# 2023-01-18 04:01:18  Density : 10.00%, slice_epochs : 60, agg_epochs : 10
# ...

# %%
# !python Experiment.py --dataset rt --interaction Pure_Mf --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --debug 1 --agg_function 2
# Out:
# 2023-01-18 04:08:00  Namespace(agg2=1, agg_epochs=10, agg_function=2, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='Pure_Mf', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice_epochs=60, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-18 04:08:00  Experiment start!
# 2023-01-18 04:08:00  Dataset : rt     interaction : Pure_Mf
# 2023-01-18 04:08:00  Density : 10.00%, slice_epochs : 60, agg_epochs : 10
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --order 0 --slice_epochs 15 --rounds 1 --agg_epochs 1 --density 0.10 --part_type 5 --debug 1 --agg_function 2
# Out:
# 2023-01-18 04:12:04  Namespace(agg2=1, agg_epochs=1, agg_function=2, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice_epochs=15, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-18 04:12:04  Experiment start!
# 2023-01-18 04:12:04  Dataset : rt     interaction : GraphMF
# 2023-01-18 04:12:04  Density : 10.00%, slice_epochs : 15, agg_epochs : 1
# ...

# %% [markdown]
# ## Dataset : tp

# %% [markdown]
# # Desity = 0.10

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --dimension 64 --rounds 1 --slice_epochs 100 --agg_epochs 5 --density 0.10 --part_type 5 --debug 1 --agg_function 2
# Out:
# 2023-01-18 04:14:31  Namespace(agg2=1, agg_epochs=5, agg_function=2, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=1, density=0.1, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice_epochs=100, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-18 04:14:31  Experiment start!
# 2023-01-18 04:14:31  Dataset : tp     interaction : NeuCF
# 2023-01-18 04:14:31  Density : 10.00%, slice_epochs : 100, agg_epochs : 5
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 60 --agg_epochs 10 --density 0.10 --part_type 5 --debug 1 --agg_function 2
# Out:
# 2023-01-18 04:22:13  Namespace(agg2=1, agg_epochs=10, agg_function=2, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice_epochs=60, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-18 04:22:13  Experiment start!
# 2023-01-18 04:22:13  Dataset : tp     interaction : CSMF
# 2023-01-18 04:22:13  Density : 10.00%, slice_epochs : 60, agg_epochs : 10
# ...

# %%
# !python Experiment.py --dataset tp --interaction Pure_Mf --rounds 1 --agg_epochs 10 --density 0.10 --part_type 5 --debug 1 --agg_function 2
# Out:
# 2023-01-18 04:28:40  Namespace(agg2=1, agg_epochs=10, agg_function=2, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='Pure_Mf', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice_epochs=60, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-18 04:28:40  Experiment start!
# 2023-01-18 04:28:40  Dataset : tp     interaction : Pure_Mf
# 2023-01-18 04:28:40  Density : 10.00%, slice_epochs : 60, agg_epochs : 10
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --order 0 --slice_epochs 15 --rounds 1 --agg_epochs 1 --density 0.10 --part_type 5 --debug 1 --agg_function 2
# Out:
# 2023-01-18 04:32:40  Namespace(agg2=1, agg_epochs=1, agg_function=2, agg_type='softmax', balance=0, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=1, density=0.1, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=50, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=1, save_model=1, slice_epochs=15, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-18 04:32:40  Experiment start!
# 2023-01-18 04:32:40  Dataset : tp     interaction : GraphMF
# 2023-01-18 04:32:40  Density : 10.00%, slice_epochs : 15, agg_epochs : 1
# ...

# %%
# !./Run_SISA.sh
# Out:
# 2023-01-18 13:18:25  Namespace(agg2=1, agg_epochs=5, agg_function=1, agg_type='mean', balance=0, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.1, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', kmeans_type=1, lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=50, part_type=1, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=1001, retrain=0, rounds=2, save_model=1, slice_epochs=100, slices=10, subagg=1, verbose=10, wd=0.0005)
# 2023-01-18 13:18:25  All the experiments have been done!
# 2023-01-18 13:18:25  Dataset : rt     interaction : NeuCF
# ...

# %%
# !./Run_RecEraser.sh # run in latptop
