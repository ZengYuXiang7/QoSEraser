# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 6 --density 0.10 --slices 10 --part_type 0 --save_model 0 --processed 0 --agg_type att --debug 1
# Out:
# 2022-12-01 14:33:08  Namespace(agg_epochs=6, agg_type='att', balance=0, batch_size=128, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=3, num_layers=2, order=2, part_iter=100, part_type=0, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=0, slice_epochs=50, slices=10, verbose=0)
# 2022-12-01 14:33:08  Experiment start!
# 2022-12-01 14:33:08  Dataset : rt     interaction : NeuCF
# 2022-12-01 14:33:08  Density : 10.00%, slice_epochs : 50, agg_epochs : 6
# 2022-12-01 14:33:08  Part_type : 0,    slices : 10,       devices : gpu
#
# 2022-12-01 14:33:08  Round 1 experiment start!
# 2022-12-01 14:33:08  	原始数据集读取完毕
# ...
# Generating walks (CPU: 1): 100%|████████████████| 50/50 [00:00<00:00, 95.06it/s]
# {0: 158, 4: 47, 7: 30, 1: 26, 2: 25, 9: 19, 3: 6, 8: 13, 5: 6, 6: 9}
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 6 --density 0.10 --slices 10 --part_type 0 --save_model 0 --processed 0 --agg_type mean --debug 0
# Out:
# 2022-12-01 15:34:00  Namespace(agg_epochs=6, agg_type='mean', balance=0, batch_size=128, dataset='rt', debug=0, density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=3, num_layers=2, order=2, part_iter=100, part_type=0, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=0, slice_epochs=50, slices=10, verbose=0)
# 2022-12-01 15:34:00  Experiment start!
# 2022-12-01 15:34:00  Dataset : rt     interaction : NeuCF
# 2022-12-01 15:34:00  Density : 10.00%, slice_epochs : 50, agg_epochs : 6
# 2022-12-01 15:34:00  Part_type : 0,    slices : 10,       devices : gpu
#
# 2022-12-01 15:34:00  Round 1 experiment start!
# 2022-12-01 15:34:00  	原始数据集读取完毕
# ...
# Generating walks (CPU: 1): 100%|████████████████| 50/50 [00:00<00:00, 58.64it/s]
# {5: 133, 4: 95, 2: 23, 6: 18, 3: 12, 1: 21, 9: 10, 7: 10, 8: 8, 0: 9}
# ...

# %% [markdown]
# *****

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 6 --density 0.10 --slices 10 --part_type 1 --save_model 0 --processed 0 --agg_type att --debug 1
# Out:
# 2022-12-01 14:41:14  Namespace(agg_epochs=6, agg_type='att', balance=0, batch_size=128, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=3, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=0, slice_epochs=50, slices=10, verbose=0)
# 2022-12-01 14:41:14  Experiment start!
# 2022-12-01 14:41:14  Dataset : rt     interaction : NeuCF
# 2022-12-01 14:41:14  Density : 10.00%, slice_epochs : 50, agg_epochs : 6
# 2022-12-01 14:41:14  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-12-01 14:41:14  Round 1 experiment start!
# 2022-12-01 14:41:14  	原始数据集读取完毕
# 123
# 2022-12-01 14:41:14  	Node2Vec 基于用户切割完毕
# 2022-12-01 14:41:14  	数据分切执行中
# 2022-12-01 14:41:28  	分切数据执行完毕
# 2022-12-01 14:41:30  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 6 --density 0.10 --slices 10 --part_type 1 --save_model 0 --processed 0 --agg_type mean --debug 0
# Out:
# 2022-12-01 15:36:58  Namespace(agg_epochs=6, agg_type='mean', balance=0, batch_size=128, dataset='rt', debug=0, density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=3, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=0, slice_epochs=50, slices=10, verbose=0)
# 2022-12-01 15:36:58  Experiment start!
# 2022-12-01 15:36:58  Dataset : rt     interaction : NeuCF
# 2022-12-01 15:36:58  Density : 10.00%, slice_epochs : 50, agg_epochs : 6
# 2022-12-01 15:36:58  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-12-01 15:36:58  Round 1 experiment start!
# 2022-12-01 15:36:58  	原始数据集读取完毕
# 123
# 2022-12-01 15:36:58  	Node2Vec 基于用户切割完毕
# 2022-12-01 15:36:58  	数据分切执行中
# 2022-12-01 15:37:17  	分切数据执行完毕
# 2022-12-01 15:37:20  	模型加载完毕
# ...

# %% [markdown]
# *****

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 6 --density 0.10 --slices 10 --part_type 2 --save_model 0 --processed 0 --agg_type att --debug 1
# Out:
# 2022-12-01 15:03:44  Namespace(agg_epochs=6, agg_type='att', balance=0, batch_size=128, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=3, num_layers=2, order=2, part_iter=100, part_type=2, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=0, slice_epochs=50, slices=10, verbose=0)
# 2022-12-01 15:03:44  Experiment start!
# 2022-12-01 15:03:44  Dataset : rt     interaction : NeuCF
# 2022-12-01 15:03:44  Density : 10.00%, slice_epochs : 50, agg_epochs : 6
# 2022-12-01 15:03:44  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-12-01 15:03:44  Round 1 experiment start!
# 2022-12-01 15:03:44  	原始数据集读取完毕
# 2022-12-01 15:03:45  	SISA 切割完毕
# 2022-12-01 15:03:45  	数据分切执行中
# 2022-12-01 15:03:58  	分切数据执行完毕
# 2022-12-01 15:04:00  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 6 --density 0.10 --slices 10 --part_type 2 --save_model 0 --processed 0 --agg_type mean --debug 1
# Out:
# 2022-12-01 15:05:24  Namespace(agg_epochs=6, agg_type='mean', balance=0, batch_size=128, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=3, num_layers=2, order=2, part_iter=100, part_type=2, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=0, slice_epochs=50, slices=10, verbose=0)
# 2022-12-01 15:05:24  Experiment start!
# 2022-12-01 15:05:24  Dataset : rt     interaction : NeuCF
# 2022-12-01 15:05:24  Density : 10.00%, slice_epochs : 50, agg_epochs : 6
# 2022-12-01 15:05:24  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-12-01 15:05:24  Round 1 experiment start!
# 2022-12-01 15:05:24  	原始数据集读取完毕
# 2022-12-01 15:05:24  	SISA 切割完毕
# 2022-12-01 15:05:24  	数据分切执行中
# 2022-12-01 15:05:37  	分切数据执行完毕
# 2022-12-01 15:05:39  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 6 --density 0.10 --slices 10 --part_type 3 --save_model 0 --processed 0 --agg_type att --debug 1
# Out:
# 2022-12-01 15:07:09  Namespace(agg_epochs=6, agg_type='att', balance=0, batch_size=128, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=3, num_layers=2, order=2, part_iter=100, part_type=3, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=0, slice_epochs=50, slices=10, verbose=0)
# 2022-12-01 15:07:09  Experiment start!
# 2022-12-01 15:07:09  Dataset : rt     interaction : NeuCF
# 2022-12-01 15:07:09  Density : 10.00%, slice_epochs : 50, agg_epochs : 6
# 2022-12-01 15:07:09  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-12-01 15:07:09  Round 1 experiment start!
# 2022-12-01 15:07:09  	原始数据集读取完毕
# 2022-12-01 15:07:10  	SISA 切割完毕
# 2022-12-01 15:07:10  	数据分切执行中
# 2022-12-01 15:07:23  	分切数据执行完毕
# 2022-12-01 15:07:25  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 6 --density 0.10 --slices 10 --part_type 3 --save_model 0 --processed 0 --agg_type mean --debug 1
# Out:
# 2022-12-01 15:08:56  Namespace(agg_epochs=6, agg_type='mean', balance=0, batch_size=128, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=3, num_layers=2, order=2, part_iter=100, part_type=3, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=0, slice_epochs=50, slices=10, verbose=0)
# 2022-12-01 15:08:56  Experiment start!
# 2022-12-01 15:08:56  Dataset : rt     interaction : NeuCF
# 2022-12-01 15:08:56  Density : 10.00%, slice_epochs : 50, agg_epochs : 6
# 2022-12-01 15:08:56  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-12-01 15:08:56  Round 1 experiment start!
# 2022-12-01 15:08:56  	原始数据集读取完毕
# 2022-12-01 15:08:56  	SISA 切割完毕
# 2022-12-01 15:08:56  	数据分切执行中
# 2022-12-01 15:09:09  	分切数据执行完毕
# 2022-12-01 15:09:11  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 6 --density 0.10 --slices 10 --part_type 4 --save_model 0 --processed 0 --agg_type att --debug 1
# Out:
# 2022-12-01 15:10:36  Namespace(agg_epochs=6, agg_type='att', balance=0, batch_size=128, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=3, num_layers=2, order=2, part_iter=100, part_type=4, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=0, slice_epochs=50, slices=10, verbose=0)
# 2022-12-01 15:10:36  Experiment start!
# 2022-12-01 15:10:36  Dataset : rt     interaction : NeuCF
# 2022-12-01 15:10:36  Density : 10.00%, slice_epochs : 50, agg_epochs : 6
# 2022-12-01 15:10:36  Part_type : 4,    slices : 10,       devices : gpu
#
# 2022-12-01 15:10:36  Round 1 experiment start!
# 2022-12-01 15:10:36  	原始数据集读取完毕
# ...
# Generating walks (CPU: 1): 100%|████████████████| 50/50 [00:32<00:00,  1.52it/s]
# 2022-12-01 15:14:18  	Node2Vec 基于服务切割完毕
# 2022-12-01 15:14:18  	数据分切执行中
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --agg_epochs 6 --density 0.10 --slices 10 --part_type 4 --save_model 0 --processed 0 --agg_type mean --debug 1
# Out:
# 2022-12-01 15:20:16  Namespace(agg_epochs=6, agg_type='mean', balance=0, batch_size=128, dataset='rt', debug=1, density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=3, num_layers=2, order=2, part_iter=100, part_type=4, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=0, slice_epochs=50, slices=10, verbose=0)
# 2022-12-01 15:20:16  Experiment start!
# 2022-12-01 15:20:16  Dataset : rt     interaction : NeuCF
# 2022-12-01 15:20:16  Density : 10.00%, slice_epochs : 50, agg_epochs : 6
# 2022-12-01 15:20:16  Part_type : 4,    slices : 10,       devices : gpu
#
# 2022-12-01 15:20:16  Round 1 experiment start!
# 2022-12-01 15:20:16  	原始数据集读取完毕
# ...
# Generating walks (CPU: 1): 100%|████████████████| 50/50 [00:48<00:00,  1.02it/s]
# 2022-12-01 15:25:53  	Node2Vec 基于服务切割完毕
# 2022-12-01 15:25:53  	数据分切执行中
# ...
