# %% [markdown]
# # Author : yuxiang Zeng

# %% [markdown]
# # NeuCF

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 20 --agg_epochs 10 --density 0.1 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0 --devices gpu --processed 0 --retrain 1
# Out:
# Using backend: pytorch
# 2022-11-14 15:16:12  Experiment start!
# 2022-11-14 15:16:12  Dataset : rt     interaction : NeuCF
# 2022-11-14 15:16:12  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-14 15:16:12  Part_type : 3,    slices : 1,       devices : gpu
#
# 2022-11-14 15:16:12  Round 1 experiment start!
# 2022-11-14 15:16:12  	原始数据集读取完毕
# 2022-11-14 15:16:12  	SISA 切割完毕
# 2022-11-14 15:16:12  	数据分切执行中
# 2022-11-14 15:16:18  	分切数据执行完毕
# 2022-11-14 15:16:20  	模型加载完毕
# 2022-11-14 15:16:20  	准备训练切片模型
# 2022-11-14 15:16:20  	实验 1 模型 1 开始分片训练
# ...
# 100%|██████████████████████████████████████| 6226/6226 [00:07<00:00, 821.85it/s]
# 2022-11-14 15:16:32  Epoch  1 : MAE : 0.7188  RMSE : 1.9479  NMAE : 0.7909  MRE : 0.6664  NPRE : 3.2223
# ...
# 100%|██████████████████████████████████████| 6226/6226 [00:07<00:00, 824.42it/s]
# 2022-11-14 15:16:43  Epoch  2 : MAE : 0.6164  RMSE : 1.7386  NMAE : 0.6783  MRE : 0.5586  NPRE : 2.6536
# ...

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 25 --agg_epochs 10 --density 0.1 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0  --devices gpu --processed 0 --retrain 1
# Out:
# Using backend: pytorch
# 2022-11-14 15:33:30  Experiment start!
# 2022-11-14 15:33:30  Dataset : tp     interaction : NeuCF
# 2022-11-14 15:33:30  Density : 10.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-14 15:33:30  Part_type : 3,    slices : 1,       devices : gpu
#
# 2022-11-14 15:33:30  Round 1 experiment start!
# 2022-11-14 15:33:30  	原始数据集读取完毕
# 2022-11-14 15:33:30  	SISA 切割完毕
# 2022-11-14 15:33:30  	数据分切执行中
# 2022-11-14 15:33:36  	分切数据执行完毕
# 2022-11-14 15:33:37  	模型加载完毕
# 2022-11-14 15:33:37  	准备训练切片模型
# 2022-11-14 15:33:38  	实验 1 模型 1 开始分片训练
# ...
# 100%|██████████████████████████████████████| 6081/6081 [00:06<00:00, 938.20it/s]
# 2022-11-14 15:33:48  Epoch  1 : MAE : 39.1645  RMSE : 110.1692  NMAE : 0.8234  MRE : 0.7740  NPRE : 5.1978
# ...
# 100%|██████████████████████████████████████| 6081/6081 [00:06<00:00, 932.82it/s]
# 2022-11-14 15:33:58  Epoch  2 : MAE : 31.1449  RMSE : 86.7914  NMAE : 0.6548  MRE : 0.6764  NPRE : 3.7229
# ...

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 20 --agg_epochs 10 --density 0.2 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0  --devices gpu --processed 0 --retrain 1
# Out:
# Using backend: pytorch
# 2022-11-14 15:54:37  Experiment start!
# 2022-11-14 15:54:37  Dataset : rt     interaction : NeuCF
# 2022-11-14 15:54:37  Density : 20.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-14 15:54:37  Part_type : 3,    slices : 1,       devices : gpu
#
# 2022-11-14 15:54:37  Round 1 experiment start!
# 2022-11-14 15:54:37  	原始数据集读取完毕
# 2022-11-14 15:54:37  	SISA 切割完毕
# 2022-11-14 15:54:37  	数据分切执行中
# 2022-11-14 15:54:43  	分切数据执行完毕
# 2022-11-14 15:54:45  	模型加载完毕
# 2022-11-14 15:54:45  	准备训练切片模型
# 2022-11-14 15:54:45  	实验 1 模型 1 开始分片训练
# ...
# 100%|██████████████████████████████████████| 5491/5491 [00:05<00:00, 931.70it/s]
# 2022-11-14 15:54:57  Epoch  1 : MAE : 0.6121  RMSE : 1.6966  NMAE : 0.6744  MRE : 0.5765  NPRE : 2.8223
# ...
# 100%|██████████████████████████████████████| 5491/5491 [00:05<00:00, 934.38it/s]
# 2022-11-14 15:55:08  Epoch  2 : MAE : 0.4926  RMSE : 1.4174  NMAE : 0.5427  MRE : 0.4969  NPRE : 2.7712
# ...

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 25 --agg_epochs 10 --density 0.2 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0  --devices gpu --processed 0 --retrain 1
# Out:
# Using backend: pytorch
# 2022-11-14 16:13:31  Experiment start!
# 2022-11-14 16:13:31  Dataset : tp     interaction : NeuCF
# 2022-11-14 16:13:31  Density : 20.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-14 16:13:31  Part_type : 3,    slices : 1,       devices : gpu
#
# 2022-11-14 16:13:31  Round 1 experiment start!
# 2022-11-14 16:13:31  	原始数据集读取完毕
# 2022-11-14 16:13:31  	SISA 切割完毕
# 2022-11-14 16:13:31  	数据分切执行中
# 2022-11-14 16:13:37  	分切数据执行完毕
# 2022-11-14 16:13:38  	模型加载完毕
# 2022-11-14 16:13:38  	准备训练切片模型
# 2022-11-14 16:13:39  	实验 1 模型 1 开始分片训练
# ...
# 100%|██████████████████████████████████████| 5361/5361 [00:05<00:00, 932.40it/s]
# 2022-11-14 16:13:50  Epoch  1 : MAE : 30.5520  RMSE : 84.8393  NMAE : 0.6416  MRE : 0.6406  NPRE : 3.5742
# ...
# 100%|██████████████████████████████████████| 5361/5361 [00:05<00:00, 931.13it/s]
# 2022-11-14 16:14:01  Epoch  2 : MAE : 25.1902  RMSE : 68.4733  NMAE : 0.5290  MRE : 0.5728  NPRE : 2.8266
# ...

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 20 --agg_epochs 10 --density 0.3 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0 --devices gpu --processed 0 --retrain 1
# Out:
# Using backend: pytorch
# 2022-11-14 16:37:08  Experiment start!
# 2022-11-14 16:37:08  Dataset : rt     interaction : NeuCF
# 2022-11-14 16:37:08  Density : 30.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-14 16:37:08  Part_type : 3,    slices : 1,       devices : gpu
#
# 2022-11-14 16:37:08  Round 1 experiment start!
# 2022-11-14 16:37:08  	原始数据集读取完毕
# 2022-11-14 16:37:09  	SISA 切割完毕
# 2022-11-14 16:37:09  	数据分切执行中
# 2022-11-14 16:37:14  	分切数据执行完毕
# 2022-11-14 16:37:15  	模型加载完毕
# 2022-11-14 16:37:15  	准备训练切片模型
# 2022-11-14 16:37:16  	实验 1 模型 1 开始分片训练
# ...
# 100%|██████████████████████████████████████| 4758/4758 [00:05<00:00, 925.77it/s]
# 2022-11-14 16:37:29  Epoch  1 : MAE : 0.5361  RMSE : 1.5433  NMAE : 0.5889  MRE : 0.5033  NPRE : 2.2928
# ...
# 100%|██████████████████████████████████████| 4758/4758 [00:05<00:00, 926.86it/s]
# 2022-11-14 16:37:42  Epoch  2 : MAE : 0.4634  RMSE : 1.3756  NMAE : 0.5090  MRE : 0.4643  NPRE : 2.0874
# ...

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 25 --agg_epochs 10 --density 0.3 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0  --devices gpu --processed 0 --retrain 1
# Out:
# Using backend: pytorch
# 2022-11-14 16:58:34  Experiment start!
# 2022-11-14 16:58:34  Dataset : tp     interaction : NeuCF
# 2022-11-14 16:58:34  Density : 30.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-14 16:58:34  Part_type : 3,    slices : 1,       devices : gpu
#
# 2022-11-14 16:58:34  Round 1 experiment start!
# 2022-11-14 16:58:35  	原始数据集读取完毕
# 2022-11-14 16:58:35  	SISA 切割完毕
# 2022-11-14 16:58:35  	数据分切执行中
# 2022-11-14 16:58:40  	分切数据执行完毕
# 2022-11-14 16:58:42  	模型加载完毕
# 2022-11-14 16:58:42  	准备训练切片模型
# 2022-11-14 16:58:42  	实验 1 模型 1 开始分片训练
# ...
# 100%|██████████████████████████████████████| 4649/4649 [00:05<00:00, 910.02it/s]
# 2022-11-14 16:58:55  Epoch  1 : MAE : 27.0922  RMSE : 74.0235  NMAE : 0.5706  MRE : 0.6219  NPRE : 2.9666
# ...
# 100%|██████████████████████████████████████| 4649/4649 [00:05<00:00, 906.82it/s]
# 2022-11-14 16:59:08  Epoch  2 : MAE : 23.2815  RMSE : 64.0529  NMAE : 0.4903  MRE : 0.5305  NPRE : 2.1974
# ...

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 20 --agg_epochs 10 --density 0.4 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0 --devices gpu --processed 0 --retrain 1
# Out:
# Using backend: pytorch
# 2022-11-14 17:24:34  Experiment start!
# 2022-11-14 17:24:34  Dataset : rt     interaction : NeuCF
# 2022-11-14 17:24:34  Density : 40.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-14 17:24:34  Part_type : 3,    slices : 1,       devices : gpu
#
# 2022-11-14 17:24:34  Round 1 experiment start!
# 2022-11-14 17:24:34  	原始数据集读取完毕
# 2022-11-14 17:24:34  	SISA 切割完毕
# 2022-11-14 17:24:34  	数据分切执行中
# 2022-11-14 17:24:39  	分切数据执行完毕
# 2022-11-14 17:24:41  	模型加载完毕
# 2022-11-14 17:24:41  	准备训练切片模型
# 2022-11-14 17:24:41  	实验 1 模型 1 开始分片训练
# ...
# 100%|██████████████████████████████████████| 4029/4029 [00:04<00:00, 909.97it/s]
# 2022-11-14 17:24:56  Epoch  1 : MAE : 0.4890  RMSE : 1.4434  NMAE : 0.5377  MRE : 0.4838  NPRE : 2.1409
# ...
# 100%|██████████████████████████████████████| 4029/4029 [00:04<00:00, 915.81it/s]
# 2022-11-14 17:25:10  Epoch  2 : MAE : 0.4314  RMSE : 1.3394  NMAE : 0.4743  MRE : 0.4385  NPRE : 1.7465
# ...

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 25 --agg_epochs 10 --density 0.4 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0  --devices gpu --processed 0 --retrain 1
# Out:
# Using backend: pytorch
# 2022-11-14 17:49:33  Experiment start!
# 2022-11-14 17:49:33  Dataset : tp     interaction : NeuCF
# 2022-11-14 17:49:33  Density : 40.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-14 17:49:33  Part_type : 3,    slices : 1,       devices : gpu
#
# 2022-11-14 17:49:33  Round 1 experiment start!
# 2022-11-14 17:49:34  	原始数据集读取完毕
# 2022-11-14 17:49:34  	SISA 切割完毕
# 2022-11-14 17:49:34  	数据分切执行中
# 2022-11-14 17:49:39  	分切数据执行完毕
# 2022-11-14 17:49:40  	模型加载完毕
# 2022-11-14 17:49:40  	准备训练切片模型
# 2022-11-14 17:49:41  	实验 1 模型 1 开始分片训练
# ...
# 100%|██████████████████████████████████████| 3939/3939 [00:04<00:00, 899.13it/s]
# 2022-11-14 17:49:55  Epoch  1 : MAE : 24.7024  RMSE : 67.3330  NMAE : 0.5206  MRE : 0.5571  NPRE : 2.5642
# ...
# 100%|██████████████████████████████████████| 3939/3939 [00:04<00:00, 896.88it/s]
# 2022-11-14 17:50:10  Epoch  2 : MAE : 22.1585  RMSE : 61.1228  NMAE : 0.4670  MRE : 0.5009  NPRE : 2.0951
# ...

# %% [markdown]
# # CSMF

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF  --rounds 5 --slice_epochs 20 --agg_epochs 10 --density 0.1 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0 --devices gpu --processed 0 --retrain 1
# Out:
# Using backend: pytorch
# 2022-11-14 18:19:33  Experiment start!
# 2022-11-14 18:19:33  Dataset : rt     interaction : CSMF
# 2022-11-14 18:19:33  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-14 18:19:33  Part_type : 3,    slices : 1,       devices : gpu
#
# 2022-11-14 18:19:33  Round 1 experiment start!
# 2022-11-14 18:19:34  	原始数据集读取完毕
# 2022-11-14 18:19:34  	SISA 切割完毕
# 2022-11-14 18:19:34  	数据分切执行中
# 2022-11-14 18:19:40  	分切数据执行完毕
# 2022-11-14 18:19:41  	模型加载完毕
# 2022-11-14 18:19:41  	准备训练切片模型
# 2022-11-14 18:19:42  	实验 1 模型 1 开始分片训练
# ...
# 100%|██████████████████████████████████████| 6220/6220 [00:12<00:00, 485.22it/s]
# 2022-11-14 18:19:59  Epoch  1 : MAE : 0.7075  RMSE : 2.0280  NMAE : 0.7784  MRE : 0.5527  NPRE : 2.2689
# ...
# 100%|██████████████████████████████████████| 6220/6220 [00:12<00:00, 483.90it/s]
# 2022-11-14 18:20:16  Epoch  2 : MAE : 0.6584  RMSE : 1.9803  NMAE : 0.7244  MRE : 0.4477  NPRE : 1.5386
# ...

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 25 --agg_epochs 10 --density 0.1 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0  --devices gpu --processed 0 --retrain 1
# Out:
# Using backend: pytorch
# 2022-11-14 18:47:34  Experiment start!
# 2022-11-14 18:47:34  Dataset : tp     interaction : CSMF
# 2022-11-14 18:47:34  Density : 10.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-14 18:47:34  Part_type : 3,    slices : 1,       devices : gpu
#
# 2022-11-14 18:47:34  Round 1 experiment start!
# 2022-11-14 18:47:34  	原始数据集读取完毕
# 2022-11-14 18:47:34  	SISA 切割完毕
# 2022-11-14 18:47:34  	数据分切执行中
# 2022-11-14 18:47:39  	分切数据执行完毕
# 2022-11-14 18:47:41  	模型加载完毕
# 2022-11-14 18:47:41  	准备训练切片模型
# 2022-11-14 18:47:41  	实验 1 模型 1 开始分片训练
# ...
# 100%|██████████████████████████████████████| 6082/6082 [00:12<00:00, 486.69it/s]
# 2022-11-14 18:47:58  Epoch  1 : MAE : 39.3451  RMSE : 113.2419  NMAE : 0.8272  MRE : 0.6814  NPRE : 5.0399
# ...
# 100%|██████████████████████████████████████| 6082/6082 [00:12<00:00, 485.63it/s]
# 2022-11-14 18:48:15  Epoch  2 : MAE : 31.5912  RMSE : 94.5048  NMAE : 0.6642  MRE : 0.5244  NPRE : 3.3513
# ...

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 20 --agg_epochs 10 --density 0.2 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0  --devices gpu --processed 0 --retrain 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 25 --agg_epochs 10 --density 0.2 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0  --devices gpu --processed 0 --retrain 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 20 --agg_epochs 10 --density 0.3 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0 --devices gpu --processed 0 --retrain 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 25 --agg_epochs 10 --density 0.3 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0  --devices gpu --processed 0 --retrain 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 20 --agg_epochs 10 --density 0.4 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0 --devices gpu --processed 0 --retrain 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 25 --agg_epochs 10 --density 0.4 --dropout 0. --slices 1 --part_type 3 --part_iter 30 --verbose 0 --save_model 0  --devices gpu --processed 0 --retrain 1

# %% [markdown]
# # not retrain

# %% [markdown]
# # slices 8

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.1 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.1 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.2 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.2 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.3 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.3 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.4 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.4 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %% [markdown]
# # slices 16

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.1 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.1 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.2 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.2 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.3 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.3 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.4 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.4 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %% [markdown]
# # slices 32

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.1 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.1 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.2 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.2 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.3 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.3 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.4 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction NeuCF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.4 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %% [markdown]
# # slices 8

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.1 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.1 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.2 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.2 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.3 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.3 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.4 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.4 --dropout 0. --slices 8 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %% [markdown]
# # slices 16

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.1 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.1 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.2 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.2 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.3 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.3 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.4 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.4 --dropout 0. --slices 16 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %% [markdown]
# # slices 32

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.1 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.1 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.2 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.2 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.3 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.3 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset rt --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.4 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1 --devices gpu --processed 1

# %%
# !python Experiment.py --path ./datasets/data/WSDREAM/ --dataset tp --interaction CSMF --rounds 5 --slice_epochs 10 --agg_epochs 10 --density 0.4 --dropout 0. --slices 32 --part_type 3 --part_iter 30 --verbose 0 --save_model 1  --devices gpu --processed 1
