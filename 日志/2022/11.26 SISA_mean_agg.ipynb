# %% [markdown]
# # Author : yuxiang Zeng

# %% [markdown]
# # Density : 0.10

# %% [markdown]
# ### SISA2

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean
# Out:
# 2022-11-26 18:18:37  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=2, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=0, slice_epochs=20, slices=10, verbose=0)
# 2022-11-26 18:18:37  Experiment start!
# 2022-11-26 18:18:37  Dataset : rt     interaction : NeuCF
# 2022-11-26 18:18:37  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-26 18:18:37  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-11-26 18:18:37  Round 1 experiment start!
# 2022-11-26 18:18:37  	原始数据集读取完毕
# 2022-11-26 18:18:37  	采用异常值处理
# 2022-11-26 18:18:38  	异常值处理完毕
# 2022-11-26 18:18:38  	SISA 切割完毕
# 2022-11-26 18:18:38  	数据分切执行中
# 2022-11-26 18:18:51  	分切数据执行完毕
# 2022-11-26 18:18:53  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean
# Out:
# 2022-11-26 18:23:55  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=2, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=0, slice_epochs=20, slices=10, verbose=0)
# 2022-11-26 18:23:55  Experiment start!
# 2022-11-26 18:23:55  Dataset : tp     interaction : NeuCF
# 2022-11-26 18:23:55  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-26 18:23:55  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-11-26 18:23:55  Round 1 experiment start!
# 2022-11-26 18:23:55  	原始数据集读取完毕
# 2022-11-26 18:23:55  	采用异常值处理
# 2022-11-26 18:23:56  	异常值处理完毕
# 2022-11-26 18:23:56  	SISA 切割完毕
# 2022-11-26 18:23:56  	数据分切执行中
# 2022-11-26 18:24:09  	分切数据执行完毕
# 2022-11-26 18:24:11  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean
# Out:
# 2022-11-26 18:29:16  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=2, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=0, slice_epochs=20, slices=10, verbose=0)
# 2022-11-26 18:29:16  Experiment start!
# 2022-11-26 18:29:16  Dataset : rt     interaction : CSMF
# 2022-11-26 18:29:16  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-26 18:29:16  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-11-26 18:29:16  Round 1 experiment start!
# 2022-11-26 18:29:17  	原始数据集读取完毕
# 2022-11-26 18:29:17  	采用异常值处理
# 2022-11-26 18:29:18  	异常值处理完毕
# 2022-11-26 18:29:18  	SISA 切割完毕
# 2022-11-26 18:29:18  	数据分切执行中
# 2022-11-26 18:29:30  	分切数据执行完毕
# 2022-11-26 18:29:33  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean
# Out:
# 2022-11-26 18:35:18  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=2, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=0, slice_epochs=20, slices=10, verbose=0)
# 2022-11-26 18:35:18  Experiment start!
# 2022-11-26 18:35:18  Dataset : tp     interaction : CSMF
# 2022-11-26 18:35:18  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-26 18:35:18  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-11-26 18:35:18  Round 1 experiment start!
# 2022-11-26 18:35:18  	原始数据集读取完毕
# 2022-11-26 18:35:19  	采用异常值处理
# 2022-11-26 18:35:20  	异常值处理完毕
# 2022-11-26 18:35:20  	SISA 切割完毕
# 2022-11-26 18:35:20  	数据分切执行中
# 2022-11-26 18:35:32  	分切数据执行完毕
# 2022-11-26 18:35:34  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction Pure_Mf --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean
# Out:
# 2022-11-26 18:42:25  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='Pure_Mf', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=2, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=0, slice_epochs=20, slices=10, verbose=0)
# 2022-11-26 18:42:25  Experiment start!
# 2022-11-26 18:42:25  Dataset : rt     interaction : Pure_Mf
# 2022-11-26 18:42:25  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-26 18:42:25  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-11-26 18:42:25  Round 1 experiment start!
# 2022-11-26 18:42:25  	原始数据集读取完毕
# 2022-11-26 18:42:25  	采用异常值处理
# 2022-11-26 18:42:26  	异常值处理完毕
# 2022-11-26 18:42:26  	SISA 切割完毕
# 2022-11-26 18:42:26  	数据分切执行中
# 2022-11-26 18:42:39  	分切数据执行完毕
# 2022-11-26 18:42:41  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction Pure_Mf --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0
Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-11-26 20:16:00  Round 1 experiment start!
# 2022-11-26 20:16:00  	原始数据集读取完毕
# 2022-11-26 20:16:00  	采用异常值处理
# 2022-11-26 20:16:01  	异常值处理完毕
# 2022-11-26 20:16:01  	SISA 切割完毕
# 2022-11-26 20:16:01  	数据分切执行中
# 2022-11-26 20:16:14  	分切数据执行完毕
# 2022-11-26 20:16:17  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction Pure_Mf --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean
# Out:
# 2022-11-26 20:24:34  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='Pure_Mf', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=2, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=0, slice_epochs=20, slices=10, verbose=0)
# 2022-11-26 20:24:34  Experiment start!
# 2022-11-26 20:24:34  Dataset : rt     interaction : Pure_Mf
# 2022-11-26 20:24:34  Density : 15.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-26 20:24:34  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-11-26 20:24:34  Round 1 experiment start!
# 2022-11-26 20:24:34  	原始数据集读取完毕
# 2022-11-26 20:24:34  	采用异常值处理
# 2022-11-26 20:24:35  	异常值处理完毕
# 2022-11-26 20:24:35  	SISA 切割完毕
# 2022-11-26 20:24:35  	数据分切执行中
# 2022-11-26 20:24:48  	分切数据执行完毕
# 2022-11-26 20:24:50  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction Pure_Mf --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean
# Out:
# 2022-11-26 20:28:54  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='tp', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='Pure_Mf', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=2, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=0, slice_epochs=20, slices=10, verbose=0)
# 2022-11-26 20:28:54  Experiment start!
# 2022-11-26 20:28:54  Dataset : tp     interaction : Pure_Mf
# 2022-11-26 20:28:54  Density : 15.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-26 20:28:54  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-11-26 20:28:54  Round 1 experiment start!
# 2022-11-26 20:28:54  	原始数据集读取完毕
# 2022-11-26 20:28:55  	采用异常值处理
# 2022-11-26 20:28:56  	异常值处理完毕
# 2022-11-26 20:28:56  	SISA 切割完毕
# 2022-11-26 20:28:56  	数据分切执行中
# 2022-11-26 20:29:08  	分切数据执行完毕
# 2022-11-26 20:29:11  	模型加载完毕
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.20

# %% [markdown]
# ### SISA2

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean
# Out:
# 2022-11-26 20:49:55  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=2, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=0, slice_epochs=20, slices=10, verbose=0)
# 2022-11-26 20:49:55  Experiment start!
# 2022-11-26 20:49:55  Dataset : rt     interaction : NeuCF
# 2022-11-26 20:49:55  Density : 20.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-26 20:49:55  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-11-26 20:49:55  Round 1 experiment start!
# 2022-11-26 20:49:55  	原始数据集读取完毕
# 2022-11-26 20:49:55  	采用异常值处理
# 2022-11-26 20:49:56  	异常值处理完毕
# 2022-11-26 20:49:56  	SISA 切割完毕
# 2022-11-26 20:49:56  	数据分切执行中
# 2022-11-26 20:50:09  	分切数据执行完毕
# 2022-11-26 20:50:11  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean
# Out:
# 2022-11-26 20:56:32  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='tp', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=2, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=0, slice_epochs=20, slices=10, verbose=0)
# 2022-11-26 20:56:32  Experiment start!
# 2022-11-26 20:56:32  Dataset : tp     interaction : NeuCF
# 2022-11-26 20:56:32  Density : 20.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-26 20:56:32  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-11-26 20:56:32  Round 1 experiment start!
# 2022-11-26 20:56:32  	原始数据集读取完毕
# 2022-11-26 20:56:32  	采用异常值处理
# 2022-11-26 20:56:33  	异常值处理完毕
# 2022-11-26 20:56:33  	SISA 切割完毕
# 2022-11-26 20:56:33  	数据分切执行中
# 2022-11-26 20:56:46  	分切数据执行完毕
# 2022-11-26 20:56:48  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean
# Out:
# 2022-11-26 20:39:31  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=2, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=0, slice_epochs=20, slices=10, verbose=0)
# 2022-11-26 20:39:31  Experiment start!
# 2022-11-26 20:39:31  Dataset : rt     interaction : CSMF
# 2022-11-26 20:39:31  Density : 20.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-26 20:39:31  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022
	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction Pure_Mf --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.30 --slices 10 --part_type 2 --save_model 0 --processed 1 --agg_type mean
# Out:
# 2022-11-26 22:42:15  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='tp', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='Pure_Mf', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=2, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=0, slice_epochs=20, slices=10, verbose=0)
# 2022-11-26 22:42:15  Experiment start!
# 2022-11-26 22:42:15  Dataset : tp     interaction : Pure_Mf
# 2022-11-26 22:42:15  Density : 30.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-26 22:42:15  Part_type : 2,    slices : 10,       devices : gpu
#
# 2022-11-26 22:42:15  Round 1 experiment start!
# 2022-11-26 22:42:15  	原始数据集读取完毕
# 2022-11-26 22:42:15  	采用异常值处理
# 2022-11-26 22:42:16  	异常值处理完毕
# 2022-11-26 22:42:16  	SISA 切割完毕
# 2022-11-26 22:42:16  	数据分切执行中
# 2022-11-26 22:42:28  	分切数据执行完毕
# 2022-11-26 22:42:30  	模型加载完毕
# ...

# %% [markdown]
# *****

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1 --processed 1 --agg_type softmax
# Out:
# 2022-11-27 01:03:40  Namespace(agg_epochs=10, agg_type='softmax', batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-27 01:03:40  Experiment start!
# 2022-11-27 01:03:40  Dataset : rt     interaction : NeuCF
# 2022-11-27 01:03:40  Density : 10.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-27 01:03:40  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 01:03:40  Round 1 experiment start!
# 2022-11-27 01:03:40  	原始数据集读取完毕
# 2022-11-27 01:03:40  	采用异常值处理
# 2022-11-27 01:03:41  	异常值处理完毕
# 2022-11-27 01:03:43  	Node2Vec 基于用户切割完毕
# 2022-11-27 01:03:43  	数据分切执行中
# 2022-11-27 01:03:56  	分切数据执行完毕
# 2022-11-27 01:03:58  	模型加载完毕
# ...

# %% [markdown]
# # Density : 0.10

# %% [markdown]
# ### SISA

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.10 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-26 22:47:25  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-26 22:47:25  Experiment start!
# 2022-11-26 22:47:25  Dataset : rt     interaction : NeuCF
# 2022-11-26 22:47:25  Density : 10.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-26 22:47:25  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-26 22:47:25  Round 1 experiment start!
# 2022-11-26 22:47:25  	原始数据集读取完毕
# 2022-11-26 22:47:25  	采用异常值处理
# 2022-11-26 22:47:26  	异常值处理完毕
# 2022-11-26 22:47:26  	SISA 切割完毕
# 2022-11-26 22:47:26  	数据分切执行中
# 2022-11-26 22:47:39  	分切数据执行完毕
# 2022-11-26 22:47:41  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.10 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-26 22:52:40  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-26 22:52:40  Experiment start!
# 2022-11-26 22:52:40  Dataset : tp     interaction : NeuCF
# 2022-11-26 22:52:40  Density : 10.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-26 22:52:40  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-26 22:52:40  Round 1 experiment start!
# 2022-11-26 22:52:40  	原始数据集读取完毕
# 2022-11-26 22:52:40  	采用异常值处理
# 2022-11-26 22:52:41  	异常值处理完毕
# 2022-11-26 22:52:41  	SISA 切割完毕
# 2022-11-26 22:52:41  	数据分切执行中
# 2022-11-26 22:52:54  	分切数据执行完毕
# 2022-11-26 22:52:56  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 15 --density 0.10 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-26 22:58:21  Namespace(agg_epochs=15, agg_type='mean', batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-26 22:58:21  Experiment start!
# 2022-11-26 22:58:21  Dataset : rt     interaction : CSMF
# 2022-11-26 22:58:21  Density : 10.00%, slice_epochs : 20, agg_epochs : 15
# 2022-11-26 22:58:21  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-26 22:58:21  Round 1 experiment start!
# 2022-11-26 22:58:21  	原始数据集读取完毕
# 2022-11-26 22:58:21  	采用异常值处理
# 2022-11-26 22:58:22  	异常值处理完毕
# 2022-11-26 22:58:22  	SISA 切割完毕
# 2022-11-26 22:58:22  	数据分切执行中
# 2022-11-26 22:58:35  	分切数据执行完毕
# 2022-11-26 22:58:38  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.10 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-26 23:05:43  Namespace(agg_epochs=15, agg_type='mean', batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-26 23:05:43  Experiment start!
# 2022-11-26 23:05:43  Dataset : tp     interaction : CSMF
# 2022-11-26 23:05:43  Density : 10.00%, slice_epochs : 25, agg_epochs : 15
# 2022-11-26 23:05:43  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-26 23:05:43  Round 1 experiment start!
# 2022-11-26 23:05:43  	原始数据集读取完毕
# 2022-11-26 23:05:43  	采用异常值处理
# 2022-11-26 23:05:44  	异常值处理完毕
# 2022-11-26 23:05:44  	SISA 切割完毕
# 2022-11-26 23:05:44  	数据分切执行中
# 2022-11-26 23:05:57  	分切数据执行完毕
# 2022-11-26 23:05:59  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction Pure_Mf --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.10 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-26 23:15:58  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='Pure_Mf', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-26 23:15:58  Experiment start!
# 2022-11-26 23:15:58  Dataset : rt     interaction : Pure_Mf
# 2022-11-26 23:15:58  Density : 10.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-26 23:15:58  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-26 23:15:58  Round 1 experiment start!
# 2022-11-26 23:15:59  	原始数据集读取完毕
# 2022-11-26 23:15:59  	采用异常值处理
# 2022-11-26 23:16:00  	异常值处理完毕
# 2022-11-26 23:16:00  	SISA 切割完毕
# 2022-11-26 23:16:00  	数据分切执行中
# 2022-11-26 23:16:13  	分切数据执行完毕
# 2022-11-26 23:16:15  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction Pure_Mf --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.10 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-26 23:20:24  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='Pure_Mf', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-26 23:20:24  Experiment start!
# 2022-11-26 23:20:24  Dataset : tp     interaction : Pure_Mf
# 2022-11-26 23:20:24  Density : 10.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-26 23:20:24  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-26 23:20:24  Round 1 experiment start!
# 2022-11-26 23:20:24  	原始数据集读取完毕
# 2022-11-26 23:20:24  	采用异常值处理
# 2022-11-26 23:20:25  	异常值处理完毕
# 2022-11-26 23:20:25  	SISA 切割完毕
# 2022-11-26 23:20:25  	数据分切执行中
# 2022-11-26 23:20:38  	分切数据执行完毕
# 2022-11-26 23:20:40  	模型加载完毕
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.15

# %% [markdown]
# ### SISA

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.15 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-26 23:24:44  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-26 23:24:44  Experiment start!
# 2022-11-26 23:24:44  Dataset : rt     interaction : NeuCF
# 2022-11-26 23:24:44  Density : 15.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-26 23:24:44  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-26 23:24:44  Round 1 experiment start!
# 2022-11-26 23:24:44  	原始数据集读取完毕
# 2022-11-26 23:24:44  	采用异常值处理
# 2022-11-26 23:24:45  	异常值处理完毕
# 2022-11-26 23:24:45  	SISA 切割完毕
# 2022-11-26 23:24:45  	数据分切执行中
# 2022-11-26 23:24:57  	分切数据执行完毕
# 2022-11-26 23:24:59  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.15 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-26 23:30:15  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='tp', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-26 23:30:15  Experiment start!
# 2022-11-26 23:30:15  Dataset : tp     interaction : NeuCF
# 2022-11-26 23:30:15  Density : 15.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-26 23:30:15  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-26 23:30:15  Round 1 experiment start!
# 2022-11-26 23:30:15  	原始数据集读取完毕
# 2022-11-26 23:30:15  	采用异常值处理
# 2022-11-26 23:30:16  	异常值处理完毕
# 2022-11-26 23:30:16  	SISA 切割完毕
# 2022-11-26 23:30:16  	数据分切执行中
# 2022-11-26 23:30:29  	分切数据执行完毕
# 2022-11-26 23:30:31  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.15 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-26 23:37:23  Namespace(agg_epochs=15, agg_type='mean', batch_size=128, dataset='rt', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-26 23:37:23  Experiment start!
# 2022-11-26 23:37:23  Dataset : rt     interaction : CSMF
# 2022-11-26 23:37:23  Density : 15.00%, slice_epochs : 25, agg_epochs : 15
# 2022-11-26 23:37:23  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-26 23:37:23  Round 1 experiment start!
# 2022-11-26 23:37:23  	原始数据集读取完毕
# 2022-11-26 23:37:23  	采用异常值处理
# 2022-11-26 23:37:24  	异常值处理完毕
# 2022-11-26 23:37:24  	SISA 切割完毕
# 2022-11-26 23:37:24  	数据分切执行中
# 2022-11-26 23:37:37  	分切数据执行完毕
# 2022-11-26 23:37:39  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.15 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-26 23:44:34  Namespace(agg_epochs=15, agg_type='mean', batch_size=128, dataset='tp', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-26 23:44:34  Experiment start!
# 2022-11-26 23:44:34  Dataset : tp     interaction : CSMF
# 2022-11-26 23:44:34  Density : 15.00%, slice_epochs : 25, agg_epochs : 15
# 2022-11-26 23:44:34  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-26 23:44:34  Round 1 experiment start!
# 2022-11-26 23:44:35  	原始数据集读取完毕
# 2022-11-26 23:44:35  	采用异常值处理
# 2022-11-26 23:44:36  	异常值处理完毕
# 2022-11-26 23:44:36  	SISA 切割完毕
# 2022-11-26 23:44:36  	数据分切执行中
# 2022-11-26 23:44:49  	分切数据执行完毕
# 2022-11-26 23:44:51  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction Pure_Mf --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.15 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-26 23:55:38  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='Pure_Mf', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-26 23:55:38  Experiment start!
# 2022-11-26 23:55:38  Dataset : rt     interaction : Pure_Mf
# 2022-11-26 23:55:38  Density : 15.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-26 23:55:38  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-26 23:55:38  Round 1 experiment start!
# 2022-11-26 23:55:38  	原始数据集读取完毕
# 2022-11-26 23:55:38  	采用异常值处理
# 2022-11-26 23:55:39  	异常值处理完毕
# 2022-11-26 23:55:39  	SISA 切割完毕
# 2022-11-26 23:55:39  	数据分切执行中
# 2022-11-26 23:55:52  	分切数据执行完毕
# 2022-11-26 23:55:54  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction Pure_Mf --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.15 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-27 00:00:18  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='tp', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='Pure_Mf', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-27 00:00:18  Experiment start!
# 2022-11-27 00:00:18  Dataset : tp     interaction : Pure_Mf
# 2022-11-27 00:00:18  Density : 15.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-27 00:00:18  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-27 00:00:18  Round 1 experiment start!
# 2022-11-27 00:00:19  	原始数据集读取完毕
# 2022-11-27 00:00:19  	采用异常值处理
# 2022-11-27 00:00:20  	异常值处理完毕
# 2022-11-27 00:00:20  	SISA 切割完毕
# 2022-11-27 00:00:20  	数据分切执行中
# 2022-11-27 00:00:33  	分切数据执行完毕
# 2022-11-27 00:00:35  	模型加载完毕
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.20

# %% [markdown]
# ### SISA

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.20 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-27 00:04:55  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-27 00:04:55  Experiment start!
# 2022-11-27 00:04:55  Dataset : rt     interaction : NeuCF
# 2022-11-27 00:04:55  Density : 20.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-27 00:04:55  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-27 00:04:55  Round 1 experiment start!
# 2022-11-27 00:04:55  	原始数据集读取完毕
# 2022-11-27 00:04:55  	采用异常值处理
# 2022-11-27 00:04:56  	异常值处理完毕
# 2022-11-27 00:04:56  	SISA 切割完毕
# 2022-11-27 00:04:56  	数据分切执行中
# 2022-11-27 00:05:09  	分切数据执行完毕
# 2022-11-27 00:05:11  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.20 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-27 00:11:18  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='tp', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-27 00:11:18  Experiment start!
# 2022-11-27 00:11:18  Dataset : tp     interaction : NeuCF
# 2022-11-27 00:11:18  Density : 20.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-27 00:11:18  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-27 00:11:18  Round 1 experiment start!
# 2022-11-27 00:11:18  	原始数据集读取完毕
# 2022-11-27 00:11:18  	采用异常值处理
# 2022-11-27 00:11:19  	异常值处理完毕
# 2022-11-27 00:11:19  	SISA 切割完毕
# 2022-11-27 00:11:19  	数据分切执行中
# 2022-11-27 00:11:32  	分切数据执行完毕
# 2022-11-27 00:11:34  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.20 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-27 00:21:35  Namespace(agg_epochs=15, agg_type='mean', batch_size=128, dataset='rt', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-27 00:21:35  Experiment start!
# 2022-11-27 00:21:35  Dataset : rt     interaction : CSMF
# 2022-11-27 00:21:35  Density : 20.00%, slice_epochs : 25, agg_epochs : 15
# 2022-11-27 00:21:35  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-27 00:21:35  Round 1 experiment start!
# 2022-11-27 00:21:35  	原始数据集读取完毕
# 2022-11-27 00:21:35  	采用异常值处理
# 2022-11-27 00:21:36  	异常值处理完毕
# 2022-11-27 00:21:36  	SISA 切割完毕
# 2022-11-27 00:21:36  	数据分切执行中
# 2022-11-27 00:21:49  	分切数据执行完毕
# 2022-11-27 00:21:51  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.20 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-27 00:29:21  Namespace(agg_epochs=15, agg_type='mean', batch_size=128, dataset='tp', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-27 00:29:21  Experiment start!
# 2022-11-27 00:29:21  Dataset : tp     interaction : CSMF
# 2022-11-27 00:29:21  Density : 20.00%, slice_epochs : 25, agg_epochs : 15
# 2022-11-27 00:29:21  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-27 00:29:21  Round 1 experiment start!
# 2022-11-27 00:29:21  	原始数据集读取完毕
# 2022-11-27 00:29:21  	采用异常值处理
# 2022-11-27 00:29:22  	异常值处理完毕
# 2022-11-27 00:29:22  	SISA 切割完毕
# 2022-11-27 00:29:22  	数据分切执行中
# 2022-11-27 00:29:35  	分切数据执行完毕
# 2022-11-27 00:29:37  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction Pure_Mf --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.20 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-27 00:41:06  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='Pure_Mf', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-27 00:41:06  Experiment start!
# 2022-11-27 00:41:06  Dataset : rt     interaction : Pure_Mf
# 2022-11-27 00:41:06  Density : 20.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-27 00:41:06  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-27 00:41:06  Round 1 experiment start!
# 2022-11-27 00:41:06  	原始数据集读取完毕
# 2022-11-27 00:41:06  	采用异常值处理
# 2022-11-27 00:41:07  	异常值处理完毕
# 2022-11-27 00:41:07  	SISA 切割完毕
# 2022-11-27 00:41:07  	数据分切执行中
# 2022-11-27 00:41:20  	分切数据执行完毕
# 2022-11-27 00:41:22  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction Pure_Mf --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.20 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-27 00:45:44  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='tp', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='Pure_Mf', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-27 00:45:44  Experiment start!
# 2022-11-27 00:45:44  Dataset : tp     interaction : Pure_Mf
# 2022-11-27 00:45:44  Density : 20.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-27 00:45:44  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-27 00:45:44  Round 1 experiment start!
# 2022-11-27 00:45:44  	原始数据集读取完毕
# 2022-11-27 00:45:44  	采用异常值处理
# 2022-11-27 00:45:45  	异常值处理完毕
# 2022-11-27 00:45:45  	SISA 切割完毕
# 2022-11-27 00:45:45  	数据分切执行中
# 2022-11-27 00:45:58  	分切数据执行完毕
# 2022-11-27 00:46:01  	模型加载完毕
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.25

# %% [markdown]
# ### SISA

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.25 --slices 10 --part_type 3 --processed 1 --agg_type mean
# Out:
# 2022-11-27 00:50:25  Namespace(agg_epochs=10, agg_type='mean', batch_size=128, dataset='rt', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=3, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=25, slices=10, verbose=0)
# 2022-11-27 00:50:25  Experiment start!
# 2022-11-27 00:50:25  Dataset : rt     interaction : NeuCF
# 2022-11-27 00:50:25  Density : 25.00%, slice_epochs : 25, agg_epochs : 10
# 2022-11-27 00:50:25  Part_type : 3,    slices : 10,       devices : gpu
#
# 2022-11-27 00:50:25  Round 1 experiment start!
# 2022-11-27 00:50:25  	原始数据集读取完毕
# 2022-11-27 00:50:25  	采用异常值处理
# 2022-11-27 00:50:26  	异常值处理完毕
# 2022-11-27 00:50:26  	SISA 切割完毕
# 2022-11-27 00:50:26  	数据分切执行中
# 2022-11-27 00:50:39  	分切数据执行完毕
# 2022-11-27 00:50:41  	模型加载完毕
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.25 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.25 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.25 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.25 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.25 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction Pure_Mf --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.25 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset tp --interaction Pure_Mf --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.25 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.30

# %% [markdown]
# ### SISA

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.30 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.30 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.30 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.30 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.30 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.30 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset rt --interaction Pure_Mf --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.30 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %%
# !python Experiment.py --dataset tp --interaction Pure_Mf --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.30 --slices 10 --part_type 3 --processed 1 --agg_type mean

# %% [markdown]
# *****

# %% [markdown]
# # balance node2vec

# %%
import pandas as pd
import numpy as np
import pickle as pk

# %%
dic = {}
for i in pk.load(open('./pretrain/user_based_10.pk', 'rb')):
    if i not in dic:
        dic[i] = 0
    else:
        dic[i] += 1
dic
# Out:
# {0: 310, 3: 3, 6: 1, 4: 3, 2: 3, 5: 1, 7: 1, 8: 2, 9: 2, 1: 3}

# %% [markdown]
# # item balance node2vec

# %% [markdown]
# # iteraction balance node2vec
