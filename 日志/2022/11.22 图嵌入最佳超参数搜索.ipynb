# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 5 --node2vec_length 10
# Out:
# 2022-11-27 20:39:32  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=5, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 20:39:32  Experiment start!
# 2022-11-27 20:39:32  Dataset : rt     interaction : NeuCF
# 2022-11-27 20:39:32  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 20:39:32  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 20:39:32  Round 1 experiment start!
# 2022-11-27 20:39:32  	原始数据集读取完毕
# 2022-11-27 20:39:32  	采用异常值处理
# 2022-11-27 20:39:33  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 103.65it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 10 --node2vec_length 10
# Out:
# 2022-11-27 20:42:13  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=10, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 20:42:13  Experiment start!
# 2022-11-27 20:42:13  Dataset : rt     interaction : NeuCF
# 2022-11-27 20:42:13  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 20:42:13  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 20:42:13  Round 1 experiment start!
# 2022-11-27 20:42:13  	原始数据集读取完毕
# 2022-11-27 20:42:13  	采用异常值处理
# 2022-11-27 20:42:14  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 104.38it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 15 --node2vec_length 10
# Out:
# 2022-11-27 20:44:45  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=15, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 20:44:45  Experiment start!
# 2022-11-27 20:44:45  Dataset : rt     interaction : NeuCF
# 2022-11-27 20:44:45  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 20:44:45  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 20:44:45  Round 1 experiment start!
# 2022-11-27 20:44:45  	原始数据集读取完毕
# 2022-11-27 20:44:45  	采用异常值处理
# 2022-11-27 20:44:46  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 104.38it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10
# Out:
# 2022-11-27 20:47:20  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 20:47:20  Experiment start!
# 2022-11-27 20:47:20  Dataset : rt     interaction : NeuCF
# 2022-11-27 20:47:20  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 20:47:20  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 20:47:20  Round 1 experiment start!
# 2022-11-27 20:47:20  	原始数据集读取完毕
# 2022-11-27 20:47:20  	采用异常值处理
# 2022-11-27 20:47:21  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 102.39it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 25 --node2vec_length 10
# Out:
# 2022-11-27 20:49:49  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=25, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 20:49:49  Experiment start!
# 2022-11-27 20:49:49  Dataset : rt     interaction : NeuCF
# 2022-11-27 20:49:49  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 20:49:49  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 20:49:49  Round 1 experiment start!
# 2022-11-27 20:49:49  	原始数据集读取完毕
# 2022-11-27 20:49:49  	采用异常值处理
# 2022-11-27 20:49:50  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 104.73it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 30 --node2vec_length 10
# Out:
# 2022-11-27 20:52:29  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=30, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 20:52:29  Experiment start!
# 2022-11-27 20:52:29  Dataset : rt     interaction : NeuCF
# 2022-11-27 20:52:29  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 20:52:29  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 20:52:29  Round 1 experiment start!
# 2022-11-27 20:52:29  	原始数据集读取完毕
# 2022-11-27 20:52:29  	采用异常值处理
# 2022-11-27 20:52:30  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 104.56it/s]
# ...

# %% [markdown]
# *****

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 32 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10
# Out:
# 2022-11-27 20:55:04  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=32, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 20:55:04  Experiment start!
# 2022-11-27 20:55:04  Dataset : rt     interaction : NeuCF
# 2022-11-27 20:55:04  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 20:55:04  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 20:55:04  Round 1 experiment start!
# 2022-11-27 20:55:04  	原始数据集读取完毕
# 2022-11-27 20:55:04  	采用异常值处理
# 2022-11-27 20:55:05  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 103.12it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 64 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10
# Out:
# 2022-11-27 20:57:33  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=64, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 20:57:33  Experiment start!
# 2022-11-27 20:57:33  Dataset : rt     interaction : NeuCF
# 2022-11-27 20:57:33  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 20:57:33  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 20:57:33  Round 1 experiment start!
# 2022-11-27 20:57:33  	原始数据集读取完毕
# 2022-11-27 20:57:33  	采用异常值处理
# 2022-11-27 20:57:34  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 103.11it/s]
# ...

# %%
# nice work
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10
# Out:
# 2022-11-27 21:00:16  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:00:16  Experiment start!
# 2022-11-27 21:00:16  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:00:16  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:00:16  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:00:16  Round 1 experiment start!
# 2022-11-27 21:00:16  	原始数据集读取完毕
# 2022-11-27 21:00:16  	采用异常值处理
# 2022-11-27 21:00:17  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 108.58it/s]
# ...

# %%
# nice work
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 256 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10
# Out:
# 2022-11-27 21:03:00  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=256, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:03:00  Experiment start!
# 2022-11-27 21:03:00  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:03:00  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:03:00  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:03:00  Round 1 experiment start!
# 2022-11-27 21:03:01  	原始数据集读取完毕
# 2022-11-27 21:03:01  	采用异常值处理
# 2022-11-27 21:03:02  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 105.53it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 512 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10
# Out:
# 2022-11-27 21:05:52  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=512, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:05:52  Experiment start!
# 2022-11-27 21:05:52  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:05:52  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:05:52  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:05:52  Round 1 experiment start!
# 2022-11-27 21:05:52  	原始数据集读取完毕
# 2022-11-27 21:05:52  	采用异常值处理
# 2022-11-27 21:05:53  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 103.16it/s]
# ...

# %% [markdown]
# *****

# %%
# nice work
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 20 --node2vec_epochs 20 --node2vec_length 10
# Out:
# 2022-11-27 21:08:26  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=20, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:08:26  Experiment start!
# 2022-11-27 21:08:26  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:08:26  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:08:26  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:08:26  Round 1 experiment start!
# 2022-11-27 21:08:26  	原始数据集读取完毕
# 2022-11-27 21:08:26  	采用异常值处理
# 2022-11-27 21:08:27  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 20/20 [00:00<00:00, 104.45it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10
# Out:
# 2022-11-27 21:11:05  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:11:05  Experiment start!
# 2022-11-27 21:11:05  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:11:05  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:11:05  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:11:05  Round 1 experiment start!
# 2022-11-27 21:11:05  	原始数据集读取完毕
# 2022-11-27 21:11:05  	采用异常值处理
# 2022-11-27 21:11:06  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 109.46it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 100 --node2vec_epochs 20 --node2vec_length 10
# Out:
# 2022-11-27 21:13:49  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=100, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:13:49  Experiment start!
# 2022-11-27 21:13:49  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:13:49  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:13:49  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:13:49  Round 1 experiment start!
# 2022-11-27 21:13:49  	原始数据集读取完毕
# 2022-11-27 21:13:49  	采用异常值处理
# 2022-11-27 21:13:50  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|█████████████| 100/100 [00:00<00:00, 102.41it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 200 --node2vec_epochs 20 --node2vec_length 10
# Out:
# 2022-11-27 21:16:29  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=200, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:16:29  Experiment start!
# 2022-11-27 21:16:29  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:16:29  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:16:29  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:16:29  Round 1 experiment start!
# 2022-11-27 21:16:29  	原始数据集读取完毕
# 2022-11-27 21:16:29  	采用异常值处理
# 2022-11-27 21:16:30  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|█████████████| 200/200 [00:01<00:00, 105.61it/s]
# ...

# %% [markdown]
# *****

# %% [markdown]
# 其他尝试

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 200 --node2vec_epochs 30 --node2vec_length 10
# Out:
# 2022-11-27 21:19:19  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=30, node2vec_length=10, node2vec_walk=200, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:19:19  Experiment start!
# 2022-11-27 21:19:19  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:19:19  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:19:19  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:19:19  Round 1 experiment start!
# 2022-11-27 21:19:19  	原始数据集读取完毕
# 2022-11-27 21:19:19  	采用异常值处理
# 2022-11-27 21:19:20  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|█████████████| 200/200 [00:01<00:00, 101.93it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 200 --node2vec_epochs 30 --node2vec_length 5
# Out:
# 2022-11-27 21:22:30  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=30, node2vec_length=5, node2vec_walk=200, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:22:30  Experiment start!
# 2022-11-27 21:22:30  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:22:30  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:22:30  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:22:30  Round 1 experiment start!
# 2022-11-27 21:22:30  	原始数据集读取完毕
# 2022-11-27 21:22:30  	采用异常值处理
# 2022-11-27 21:22:31  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|█████████████| 200/200 [00:00<00:00, 227.17it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 256 --node2vec_walk 200 --node2vec_epochs 30 --node2vec_length 5
# Out:
# 2022-11-27 21:25:54  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=256, node2vec_epochs=30, node2vec_length=5, node2vec_walk=200, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:25:54  Experiment start!
# 2022-11-27 21:25:54  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:25:54  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:25:54  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:25:54  Round 1 experiment start!
# 2022-11-27 21:25:54  	原始数据集读取完毕
# 2022-11-27 21:25:54  	采用异常值处理
# 2022-11-27 21:25:55  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|█████████████| 200/200 [00:00<00:00, 220.20it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 256 --node2vec_walk 300 --node2vec_epochs 30 --node2vec_length 5
# Out:
# 2022-11-27 21:28:59  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=256, node2vec_epochs=30, node2vec_length=5, node2vec_walk=300, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:28:59  Experiment start!
# 2022-11-27 21:28:59  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:28:59  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:28:59  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:28:59  Round 1 experiment start!
# 2022-11-27 21:28:59  	原始数据集读取完毕
# 2022-11-27 21:29:00  	采用异常值处理
# 2022-11-27 21:29:01  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|█████████████| 300/300 [00:01<00:00, 217.26it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 256 --node2vec_walk 200 --node2vec_epochs 30 --node2vec_length 10
# Out:
# 2022-11-27 21:32:07  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=256, node2vec_epochs=30, node2vec_length=10, node2vec_walk=200, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:32:07  Experiment start!
# 2022-11-27 21:32:07  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:32:07  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:32:07  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:32:07  Round 1 experiment start!
# 2022-11-27 21:32:07  	原始数据集读取完毕
# 2022-11-27 21:32:07  	采用异常值处理
# 2022-11-27 21:32:08  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|█████████████| 200/200 [00:01<00:00, 102.38it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 256 --node2vec_walk 200 --node2vec_epochs 50 --node2vec_length 10
# Out:
# 2022-11-27 21:35:35  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=256, node2vec_epochs=50, node2vec_length=10, node2vec_walk=200, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:35:35  Experiment start!
# 2022-11-27 21:35:35  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:35:35  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:35:35  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:35:35  Round 1 experiment start!
# 2022-11-27 21:35:35  	原始数据集读取完毕
# 2022-11-27 21:35:35  	采用异常值处理
# 2022-11-27 21:35:36  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|█████████████| 200/200 [00:01<00:00, 102.47it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 200 --node2vec_epochs 50 --node2vec_length 10
# Out:
# 2022-11-27 21:39:38  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=50, node2vec_length=10, node2vec_walk=200, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:39:38  Experiment start!
# 2022-11-27 21:39:38  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:39:38  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:39:38  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:39:38  Round 1 experiment start!
# 2022-11-27 21:39:38  	原始数据集读取完毕
# 2022-11-27 21:39:38  	采用异常值处理
# 2022-11-27 21:39:39  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|█████████████| 200/200 [00:01<00:00, 101.52it/s]
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 200 --node2vec_epochs 50 --node2vec_length 20

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 200 --node2vec_epochs 100 --node2vec_length 20

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 200 --node2vec_epochs 150 --node2vec_length 20

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 256 --node2vec_walk 200 --node2vec_epochs 150 --node2vec_length 20

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 256 --node2vec_walk 200 --node2vec_epochs 150 --node2vec_length 15

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 256 --node2vec_walk 200 --node2vec_epochs 100 --node2vec_length 10

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 1000 --node2vec_length 20

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 100 --node2vec_epochs 1000 --node2vec_length 10

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 25 --node2vec_epochs 1000 --node2vec_length 10

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 75 --node2vec_epochs 1000 --node2vec_length 10

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 40 --node2vec_epochs 1000 --node2vec_length 10

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 60 --node2vec_epochs 1000 --node2vec_length 20

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 200 --node2vec_epochs 1000 --node2vec_length 20

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 300 --node2vec_epochs 1000 --node2vec_length 20

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 1000 --node2vec_length 20

# %% [markdown]
# *****

# %%
# nice work
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 0 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10 --balance 1
# Out:
# 2022-11-27 21:47:05  Namespace(agg_epochs=10, agg_type='softmax', balance=1, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:47:05  Experiment start!
# 2022-11-27 21:47:05  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:47:05  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:47:05  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:47:05  Round 1 experiment start!
# 2022-11-27 21:47:05  	原始数据集读取完毕
# ...
# Generating walks (CPU: 1): 100%|████████████████| 50/50 [00:00<00:00, 96.17it/s]
# 2022-11-27 21:47:13  	Node2Vec 基于用户切割完毕
# 2022-11-27 21:47:13  	数据分切执行中
# ...

# %%
# nice work
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 0 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10 --balance 0
# Out:
# 2022-11-27 21:57:02  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:57:02  Experiment start!
# 2022-11-27 21:57:02  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:57:02  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:57:02  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:57:02  Round 1 experiment start!
# 2022-11-27 21:57:02  	原始数据集读取完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 105.23it/s]
# {1: 114, 7: 40, 4: 39, 0: 25, 5: 21, 6: 9, 2: 14, 8: 50, 3: 13, 9: 14}
# ...

# %%
# nice work
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10 --balance 1
# Out:
# 2022-11-27 21:51:35  Namespace(agg_epochs=10, agg_type='softmax', balance=1, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 21:51:35  Experiment start!
# 2022-11-27 21:51:35  Dataset : rt     interaction : NeuCF
# 2022-11-27 21:51:35  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 21:51:35  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 21:51:35  Round 1 experiment start!
# 2022-11-27 21:51:35  	原始数据集读取完毕
# 2022-11-27 21:51:35  	采用异常值处理
# 2022-11-27 21:51:36  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 100.14it/s]
# ...

# %%
# nice work
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10 --balance 0
# Out:
# 2022-11-27 22:01:38  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 22:01:38  Experiment start!
# 2022-11-27 22:01:38  Dataset : rt     interaction : NeuCF
# 2022-11-27 22:01:38  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 22:01:38  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 22:01:38  Round 1 experiment start!
# 2022-11-27 22:01:38  	原始数据集读取完毕
# 2022-11-27 22:01:38  	采用异常值处理
# 2022-11-27 22:01:39  	异常值处理完毕
# ...
# Generating walks (CPU: 1): 100%|███████████████| 50/50 [00:00<00:00, 105.82it/s]
# ...

# %%
# nice work
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 1 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10 --balance 1 --kmeans_type 0
# Out:
# 2022-11-27 22:22:46  Namespace(agg_epochs=10, agg_type='softmax', balance=1, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=0, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 22:22:46  Experiment start!
# 2022-11-27 22:22:46  Dataset : rt     interaction : NeuCF
# 2022-11-27 22:22:46  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 22:22:46  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 22:22:46  Round 1 experiment start!
# 2022-11-27 22:22:46  	原始数据集读取完毕
# 2022-11-27 22:22:47  	采用异常值处理
# 2022-11-27 22:22:48  	异常值处理完毕
# 100%|███████████████████████████████████████| 1000/1000 [01:32<00:00, 10.79it/s]
# ...

# %%
# nice work
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 0 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10 --balance 0 --kmeans_type 0
# Out:
# 2022-11-27 22:08:24  Namespace(agg_epochs=10, agg_type='softmax', balance=0, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=0, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 22:08:24  Experiment start!
# 2022-11-27 22:08:24  Dataset : rt     interaction : NeuCF
# 2022-11-27 22:08:24  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 22:08:24  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 22:08:24  Round 1 experiment start!
# 2022-11-27 22:08:24  	原始数据集读取完毕
# 100%|███████████████████████████████████████| 1000/1000 [01:31<00:00, 10.91it/s]
# 2022-11-27 22:09:58  	Node2vec loss = 0.7383
# ...

# %%
# nice work
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --density 0.10 --processed 0 --node2vec_dim 128 --node2vec_walk 50 --node2vec_epochs 20 --node2vec_length 10 --balance 1 --kmeans_type 0
# Out:
# 2022-11-27 22:14:21  Namespace(agg_epochs=10, agg_type='softmax', balance=1, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', kmeans_type=0, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=10, node2vec_walk=50, node2vec_windows=2, num_layers=2, order=2, part_iter=100, part_type=1, path='./datasets/data/WSDREAM/', processed=0, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-27 22:14:21  Experiment start!
# 2022-11-27 22:14:21  Dataset : rt     interaction : NeuCF
# 2022-11-27 22:14:21  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-27 22:14:21  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-27 22:14:21  Round 1 experiment start!
# 2022-11-27 22:14:21  	原始数据集读取完毕
# 100%|███████████████████████████████████████| 1000/1000 [01:34<00:00, 10.55it/s]
# 2022-11-27 22:15:58  	Node2vec loss = 0.7200
# ...
