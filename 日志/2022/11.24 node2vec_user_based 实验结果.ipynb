# %% [markdown]
# # RecEarser

# %% [markdown]
# # Density : 0.10

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 03:08:17  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 03:08:17  Experiment start!
# 2022-11-25 03:08:17  Dataset : rt     interaction : NeuCF
# 2022-11-25 03:08:17  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 03:08:17  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 03:08:17  Round 1 experiment start!
# 2022-11-25 03:08:17  	原始数据集读取完毕
# 2022-11-25 03:08:17  	采用异常值处理
# 2022-11-25 03:08:18  	异常值处理完毕
# 2022-11-25 03:08:18  	Node2Vec 基于用户切割完毕
# 2022-11-25 03:08:18  	数据分切执行中
# 2022-11-25 03:08:31  	分切数据执行完毕
# 2022-11-25 03:08:33  	模型加载完毕
# 2022-11-25 03:08:33  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 03:13:22  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 03:13:22  Experiment start!
# 2022-11-25 03:13:22  Dataset : tp     interaction : NeuCF
# 2022-11-25 03:13:22  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 03:13:22  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 03:13:22  Round 1 experiment start!
# 2022-11-25 03:13:22  	原始数据集读取完毕
# 2022-11-25 03:13:22  	采用异常值处理
# 2022-11-25 03:13:23  	异常值处理完毕
# 2022-11-25 03:13:23  	Node2Vec 基于用户切割完毕
# 2022-11-25 03:13:23  	数据分切执行中
# 2022-11-25 03:13:36  	分切数据执行完毕
# 2022-11-25 03:13:38  	模型加载完毕
# 2022-11-25 03:13:38  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 03:18:10  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 03:18:10  Experiment start!
# 2022-11-25 03:18:10  Dataset : rt     interaction : CSMF
# 2022-11-25 03:18:10  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 03:18:10  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 03:18:10  Round 1 experiment start!
# 2022-11-25 03:18:10  	原始数据集读取完毕
# 2022-11-25 03:18:10  	采用异常值处理
# 2022-11-25 03:18:11  	异常值处理完毕
# 2022-11-25 03:18:11  	Node2Vec 基于用户切割完毕
# 2022-11-25 03:18:11  	数据分切执行中
# 2022-11-25 03:18:24  	分切数据执行完毕
# 2022-11-25 03:18:26  	模型加载完毕
# 2022-11-25 03:18:26  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 03:24:36  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 03:24:36  Experiment start!
# 2022-11-25 03:24:36  Dataset : tp     interaction : CSMF
# 2022-11-25 03:24:36  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 03:24:36  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 03:24:36  Round 1 experiment start!
# 2022-11-25 03:24:36  	原始数据集读取完毕
# 2022-11-25 03:24:36  	采用异常值处理
# 2022-11-25 03:24:37  	异常值处理完毕
# 2022-11-25 03:24:38  	Node2Vec 基于用户切割完毕
# 2022-11-25 03:24:38  	数据分切执行中
# 2022-11-25 03:24:50  	分切数据执行完毕
# 2022-11-25 03:24:52  	模型加载完毕
# 2022-11-25 03:24:52  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 03:31:01  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 03:31:01  Experiment start!
# 2022-11-25 03:31:01  Dataset : rt     interaction : NeuGraphMF
# 2022-11-25 03:31:01  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 03:31:01  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 03:31:01  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 03:31:01  Round 1 experiment start!
# 2022-11-25 03:31:01  	原始数据集读取完毕
# 2022-11-25 03:31:01  	采用异常值处理
# 2022-11-25 03:31:02  	异常值处理完毕
# 2022-11-25 03:31:02  	Node2Vec 基于用户切割完毕
# 2022-11-25 03:31:02  	数据分切执行中
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 03:40:23  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 03:40:23  Experiment start!
# 2022-11-25 03:40:23  Dataset : tp     interaction : NeuGraphMF
# 2022-11-25 03:40:23  Density : 10.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 03:40:23  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 03:40:23  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 03:40:23  Round 1 experiment start!
# 2022-11-25 03:40:23  	原始数据集读取完毕
# 2022-11-25 03:40:23  	采用异常值处理
# 2022-11-25 03:40:24  	异常值处理完毕
# 2022-11-25 03:40:24  	Node2Vec 基于用户切割完毕
# 2022-11-25 03:40:24  	数据分切执行中
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.15

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 03:49:38  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 03:49:38  Experiment start!
# 2022-11-25 03:49:38  Dataset : rt     interaction : NeuCF
# 2022-11-25 03:49:38  Density : 15.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 03:49:38  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 03:49:38  Round 1 experiment start!
# 2022-11-25 03:49:39  	原始数据集读取完毕
# 2022-11-25 03:49:39  	采用异常值处理
# 2022-11-25 03:49:40  	异常值处理完毕
# 2022-11-25 03:49:40  	Node2Vec 基于用户切割完毕
# 2022-11-25 03:49:40  	数据分切执行中
# 2022-11-25 03:49:52  	分切数据执行完毕
# 2022-11-25 03:49:54  	模型加载完毕
# 2022-11-25 03:49:54  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 03:54:53  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 03:54:53  Experiment start!
# 2022-11-25 03:54:53  Dataset : tp     interaction : NeuCF
# 2022-11-25 03:54:53  Density : 15.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 03:54:53  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 03:54:53  Round 1 experiment start!
# 2022-11-25 03:54:53  	原始数据集读取完毕
# 2022-11-25 03:54:53  	采用异常值处理
# 2022-11-25 03:54:54  	异常值处理完毕
# 2022-11-25 03:54:54  	Node2Vec 基于用户切割完毕
# 2022-11-25 03:54:54  	数据分切执行中
# 2022-11-25 03:55:07  	分切数据执行完毕
# 2022-11-25 03:55:09  	模型加载完毕
# 2022-11-25 03:55:09  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 04:00:09  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 04:00:09  Experiment start!
# 2022-11-25 04:00:09  Dataset : rt     interaction : CSMF
# 2022-11-25 04:00:09  Density : 15.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 04:00:09  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 04:00:09  Round 1 experiment start!
# 2022-11-25 04:00:09  	原始数据集读取完毕
# 2022-11-25 04:00:09  	采用异常值处理
# 2022-11-25 04:00:10  	异常值处理完毕
# 2022-11-25 04:00:10  	Node2Vec 基于用户切割完毕
# 2022-11-25 04:00:10  	数据分切执行中
# 2022-11-25 04:00:22  	分切数据执行完毕
# 2022-11-25 04:00:24  	模型加载完毕
# 2022-11-25 04:00:24  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 04:06:48  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 04:06:48  Experiment start!
# 2022-11-25 04:06:48  Dataset : tp     interaction : CSMF
# 2022-11-25 04:06:48  Density : 15.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 04:06:48  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 04:06:48  Round 1 experiment start!
# 2022-11-25 04:06:48  	原始数据集读取完毕
# 2022-11-25 04:06:49  	采用异常值处理
# 2022-11-25 04:06:49  	异常值处理完毕
# 2022-11-25 04:06:49  	Node2Vec 基于用户切割完毕
# 2022-11-25 04:06:49  	数据分切执行中
# 2022-11-25 04:07:02  	分切数据执行完毕
# 2022-11-25 04:07:04  	模型加载完毕
# 2022-11-25 04:07:04  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 04:13:28  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 04:13:28  Experiment start!
# 2022-11-25 04:13:28  Dataset : rt     interaction : NeuGraphMF
# 2022-11-25 04:13:28  Density : 15.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 04:13:28  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 04:13:28  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 04:13:28  Round 1 experiment start!
# 2022-11-25 04:13:28  	原始数据集读取完毕
# 2022-11-25 04:13:28  	采用异常值处理
# 2022-11-25 04:13:29  	异常值处理完毕
# 2022-11-25 04:13:29  	Node2Vec 基于用户切割完毕
# 2022-11-25 04:13:29  	数据分切执行中
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 04:23:25  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 04:23:25  Experiment start!
# 2022-11-25 04:23:25  Dataset : tp     interaction : NeuGraphMF
# 2022-11-25 04:23:25  Density : 15.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 04:23:25  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 04:23:25  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 04:23:25  Round 1 experiment start!
# 2022-11-25 04:23:25  	原始数据集读取完毕
# 2022-11-25 04:23:26  	采用异常值处理
# 2022-11-25 04:23:27  	异常值处理完毕
# 2022-11-25 04:23:27  	Node2Vec 基于用户切割完毕
# 2022-11-25 04:23:27  	数据分切执行中
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.20

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.20 --slices 10 --part_type 1
# Out:
# 2022-11-25 04:33:52  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 04:33:52  Experiment start!
# 2022-11-25 04:33:52  Dataset : rt     interaction : NeuCF
# 2022-11-25 04:33:52  Density : 20.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 04:33:52  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 04:33:52  Round 1 experiment start!
# 2022-11-25 04:33:52  	原始数据集读取完毕
# 2022-11-25 04:33:52  	采用异常值处理
# 2022-11-25 04:33:53  	异常值处理完毕
# 2022-11-25 04:33:53  	Node2Vec 基于用户切割完毕
# 2022-11-25 04:33:53  	数据分切执行中
# 2022-11-25 04:34:06  	分切数据执行完毕
# 2022-11-25 04:34:08  	模型加载完毕
# 2022-11-25 04:34:08  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.20 --slices 10 --part_type 1
# Out:
# 2022-11-25 04:39:41  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 04:39:41  Experiment start!
# 2022-11-25 04:39:41  Dataset : tp     interaction : NeuCF
# 2022-11-25 04:39:41  Density : 20.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 04:39:41  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 04:39:41  Round 1 experiment start!
# 2022-11-25 04:39:41  	原始数据集读取完毕
# 2022-11-25 04:39:42  	采用异常值处理
# 2022-11-25 04:39:42  	异常值处理完毕
# 2022-11-25 04:39:42  	Node2Vec 基于用户切割完毕
# 2022-11-25 04:39:43  	数据分切执行中
# 2022-11-25 04:39:55  	分切数据执行完毕
# 2022-11-25 04:39:57  	模型加载完毕
# 2022-11-25 04:39:57  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.20 --slices 10 --part_type 1
# Out:
# 2022-11-25 04:45:20  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 04:45:20  Experiment start!
# 2022-11-25 04:45:20  Dataset : rt     interaction : CSMF
# 2022-11-25 04:45:20  Density : 20.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 04:45:20  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 04:45:20  Round 1 experiment start!
# 2022-11-25 04:45:20  	原始数据集读取完毕
# 2022-11-25 04:45:20  	采用异常值处理
# 2022-11-25 04:45:21  	异常值处理完毕
# 2022-11-25 04:45:21  	Node2Vec 基于用户切割完毕
# 2022-11-25 04:45:21  	数据分切执行中
# 2022-11-25 04:45:34  	分切数据执行完毕
# 2022-11-25 04:45:36  	模型加载完毕
# 2022-11-25 04:45:36  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.20 --slices 10 --part_type 1
# Out:
# 2022-11-25 04:52:12  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 04:52:12  Experiment start!
# 2022-11-25 04:52:12  Dataset : tp     interaction : CSMF
# 2022-11-25 04:52:12  Density : 20.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 04:52:12  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 04:52:12  Round 1 experiment start!
# 2022-11-25 04:52:12  	原始数据集读取完毕
# 2022-11-25 04:52:12  	采用异常值处理
# 2022-11-25 04:52:13  	异常值处理完毕
# 2022-11-25 04:52:13  	Node2Vec 基于用户切割完毕
# 2022-11-25 04:52:13  	数据分切执行中
# 2022-11-25 04:52:25  	分切数据执行完毕
# 2022-11-25 04:52:27  	模型加载完毕
# 2022-11-25 04:52:27  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.20 --slices 10 --part_type 1
# Out:
# 2022-11-25 04:59:07  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 04:59:07  Experiment start!
# 2022-11-25 04:59:07  Dataset : rt     interaction : NeuGraphMF
# 2022-11-25 04:59:07  Density : 20.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 04:59:07  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 04:59:07  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 04:59:07  Round 1 experiment start!
# 2022-11-25 04:59:07  	原始数据集读取完毕
# 2022-11-25 04:59:07  	采用异常值处理
# 2022-11-25 04:59:08  	异常值处理完毕
# 2022-11-25 04:59:08  	Node2Vec 基于用户切割完毕
# 2022-11-25 04:59:08  	数据分切执行中
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.20 --slices 10 --part_type 1
# Out:
# 2022-11-25 05:10:29  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 05:10:29  Experiment start!
# 2022-11-25 05:10:29  Dataset : tp     interaction : NeuGraphMF
# 2022-11-25 05:10:29  Density : 20.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 05:10:29  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 05:10:29  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 05:10:29  Round 1 experiment start!
# 2022-11-25 05:10:29  	原始数据集读取完毕
# 2022-11-25 05:10:29  	采用异常值处理
# 2022-11-25 05:10:30  	异常值处理完毕
# 2022-11-25 05:10:30  	Node2Vec 基于用户切割完毕
# 2022-11-25 05:10:30  	数据分切执行中
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.25

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.25 --slices 10 --part_type 1
# Out:
# 2022-11-25 05:21:44  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 05:21:44  Experiment start!
# 2022-11-25 05:21:44  Dataset : rt     interaction : NeuCF
# 2022-11-25 05:21:44  Density : 25.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 05:21:44  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 05:21:44  Round 1 experiment start!
# 2022-11-25 05:21:44  	原始数据集读取完毕
# 2022-11-25 05:21:44  	采用异常值处理
# 2022-11-25 05:21:45  	异常值处理完毕
# 2022-11-25 05:21:45  	Node2Vec 基于用户切割完毕
# 2022-11-25 05:21:45  	数据分切执行中
# 2022-11-25 05:21:57  	分切数据执行完毕
# 2022-11-25 05:21:59  	模型加载完毕
# 2022-11-25 05:21:59  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.25 --slices 10 --part_type 1
# Out:
# 2022-11-25 05:27:56  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 05:27:56  Experiment start!
# 2022-11-25 05:27:56  Dataset : tp     interaction : NeuCF
# 2022-11-25 05:27:56  Density : 25.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 05:27:56  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 05:27:56  Round 1 experiment start!
# 2022-11-25 05:27:56  	原始数据集读取完毕
# 2022-11-25 05:27:56  	采用异常值处理
# 2022-11-25 05:27:57  	异常值处理完毕
# 2022-11-25 05:27:57  	Node2Vec 基于用户切割完毕
# 2022-11-25 05:27:57  	数据分切执行中
# 2022-11-25 05:28:10  	分切数据执行完毕
# 2022-11-25 05:28:12  	模型加载完毕
# 2022-11-25 05:28:12  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.25 --slices 10 --part_type 1
# Out:
# 2022-11-25 05:34:01  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 05:34:01  Experiment start!
# 2022-11-25 05:34:01  Dataset : rt     interaction : CSMF
# 2022-11-25 05:34:01  Density : 25.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 05:34:01  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 05:34:01  Round 1 experiment start!
# 2022-11-25 05:34:01  	原始数据集读取完毕
# 2022-11-25 05:34:01  	采用异常值处理
# 2022-11-25 05:34:02  	异常值处理完毕
# 2022-11-25 05:34:02  	Node2Vec 基于用户切割完毕
# 2022-11-25 05:34:02  	数据分切执行中
# 2022-11-25 05:34:15  	分切数据执行完毕
# 2022-11-25 05:34:17  	模型加载完毕
# 2022-11-25 05:34:17  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.25 --slices 10 --part_type 1
# Out:
# 2022-11-25 05:41:25  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 05:41:25  Experiment start!
# 2022-11-25 05:41:25  Dataset : tp     interaction : CSMF
# 2022-11-25 05:41:25  Density : 25.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 05:41:25  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 05:41:25  Round 1 experiment start!
# 2022-11-25 05:41:25  	原始数据集读取完毕
# 2022-11-25 05:41:25  	采用异常值处理
# 2022-11-25 05:41:26  	异常值处理完毕
# 2022-11-25 05:41:26  	Node2Vec 基于用户切割完毕
# 2022-11-25 05:41:26  	数据分切执行中
# 2022-11-25 05:41:38  	分切数据执行完毕
# 2022-11-25 05:41:40  	模型加载完毕
# 2022-11-25 05:41:40  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.25 --slices 10 --part_type 1
# Out:
# 2022-11-25 05:48:28  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 05:48:28  Experiment start!
# 2022-11-25 05:48:28  Dataset : rt     interaction : NeuGraphMF
# 2022-11-25 05:48:28  Density : 25.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 05:48:28  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 05:48:28  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 05:48:28  Round 1 experiment start!
# 2022-11-25 05:48:28  	原始数据集读取完毕
# 2022-11-25 05:48:28  	采用异常值处理
# 2022-11-25 05:48:29  	异常值处理完毕
# 2022-11-25 05:48:29  	Node2Vec 基于用户切割完毕
# 2022-11-25 05:48:29  	数据分切执行中
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.25 --slices 10 --part_type 1
# Out:
# 2022-11-25 06:00:06  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 06:00:06  Experiment start!
# 2022-11-25 06:00:06  Dataset : tp     interaction : NeuGraphMF
# 2022-11-25 06:00:06  Density : 25.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 06:00:06  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 06:00:06  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 06:00:06  Round 1 experiment start!
# 2022-11-25 06:00:06  	原始数据集读取完毕
# 2022-11-25 06:00:06  	采用异常值处理
# 2022-11-25 06:00:07  	异常值处理完毕
# 2022-11-25 06:00:07  	Node2Vec 基于用户切割完毕
# 2022-11-25 06:00:07  	数据分切执行中
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.30

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.30 --slices 10 --part_type 1
# Out:
# 2022-11-25 06:12:08  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 06:12:08  Experiment start!
# 2022-11-25 06:12:08  Dataset : rt     interaction : NeuCF
# 2022-11-25 06:12:08  Density : 30.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 06:12:08  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 06:12:08  Round 1 experiment start!
# 2022-11-25 06:12:08  	原始数据集读取完毕
# 2022-11-25 06:12:08  	采用异常值处理
# 2022-11-25 06:12:09  	异常值处理完毕
# 2022-11-25 06:12:09  	Node2Vec 基于用户切割完毕
# 2022-11-25 06:12:09  	数据分切执行中
# 2022-11-25 06:12:20  	分切数据执行完毕
# 2022-11-25 06:12:22  	模型加载完毕
# 2022-11-25 06:12:22  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.30 --slices 10 --part_type 1
# Out:
# 2022-11-25 06:18:45  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 06:18:45  Experiment start!
# 2022-11-25 06:18:45  Dataset : tp     interaction : NeuCF
# 2022-11-25 06:18:45  Density : 30.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 06:18:45  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 06:18:45  Round 1 experiment start!
# 2022-11-25 06:18:45  	原始数据集读取完毕
# 2022-11-25 06:18:45  	采用异常值处理
# 2022-11-25 06:18:46  	异常值处理完毕
# 2022-11-25 06:18:46  	Node2Vec 基于用户切割完毕
# 2022-11-25 06:18:46  	数据分切执行中
# 2022-11-25 06:18:57  	分切数据执行完毕
# 2022-11-25 06:18:58  	模型加载完毕
# 2022-11-25 06:18:58  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.30 --slices 10 --part_type 1
# Out:
# 2022-11-25 06:25:10  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 06:25:10  Experiment start!
# 2022-11-25 06:25:10  Dataset : rt     interaction : CSMF
# 2022-11-25 06:25:10  Density : 30.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 06:25:10  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 06:25:10  Round 1 experiment start!
# 2022-11-25 06:25:10  	原始数据集读取完毕
# 2022-11-25 06:25:10  	采用异常值处理
# 2022-11-25 06:25:11  	异常值处理完毕
# 2022-11-25 06:25:11  	Node2Vec 基于用户切割完毕
# 2022-11-25 06:25:11  	数据分切执行中
# 2022-11-25 06:25:22  	分切数据执行完毕
# 2022-11-25 06:25:24  	模型加载完毕
# 2022-11-25 06:25:24  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.30 --slices 10 --part_type 1
# Out:
# 2022-11-25 06:32:42  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 06:32:42  Experiment start!
# 2022-11-25 06:32:42  Dataset : tp     interaction : CSMF
# 2022-11-25 06:32:42  Density : 30.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 06:32:42  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 06:32:42  Round 1 experiment start!
# 2022-11-25 06:32:42  	原始数据集读取完毕
# 2022-11-25 06:32:42  	采用异常值处理
# 2022-11-25 06:32:43  	异常值处理完毕
# 2022-11-25 06:32:43  	Node2Vec 基于用户切割完毕
# 2022-11-25 06:32:43  	数据分切执行中
# 2022-11-25 06:32:55  	分切数据执行完毕
# 2022-11-25 06:32:57  	模型加载完毕
# 2022-11-25 06:32:57  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.30 --slices 10 --part_type 1
# Out:
# 2022-11-25 06:40:10  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 06:40:10  Experiment start!
# 2022-11-25 06:40:10  Dataset : rt     interaction : NeuGraphMF
# 2022-11-25 06:40:10  Density : 30.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 06:40:10  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 06:40:10  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 06:40:10  Round 1 experiment start!
# 2022-11-25 06:40:11  	原始数据集读取完毕
# 2022-11-25 06:40:11  	采用异常值处理
# 2022-11-25 06:40:12  	异常值处理完毕
# 2022-11-25 06:40:12  	Node2Vec 基于用户切割完毕
# 2022-11-25 06:40:12  	数据分切执行中
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 10 --agg_epochs 10 --density 0.30 --slices 10 --part_type 1
# Out:
# 2022-11-25 06:52:55  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 06:52:55  Experiment start!
# 2022-11-25 06:52:55  Dataset : tp     interaction : NeuGraphMF
# 2022-11-25 06:52:55  Density : 30.00%, slice_epochs : 10, agg_epochs : 10
# 2022-11-25 06:52:55  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 06:52:55  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 06:52:55  Round 1 experiment start!
# 2022-11-25 06:52:55  	原始数据集读取完毕
# 2022-11-25 06:52:56  	采用异常值处理
# 2022-11-25 06:52:56  	异常值处理完毕
# 2022-11-25 06:52:57  	Node2Vec 基于用户切割完毕
# 2022-11-25 06:52:57  	数据分切执行中
# ...

# %% [markdown]
# # RecEarser 实验2

# %% [markdown]
# # Density : 0.10

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 07:05:41  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 07:05:41  Experiment start!
# 2022-11-25 07:05:41  Dataset : rt     interaction : NeuCF
# 2022-11-25 07:05:41  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 07:05:41  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 07:05:41  Round 1 experiment start!
# 2022-11-25 07:05:41  	原始数据集读取完毕
# 2022-11-25 07:05:41  	采用异常值处理
# 2022-11-25 07:05:42  	异常值处理完毕
# 2022-11-25 07:05:42  	Node2Vec 基于用户切割完毕
# 2022-11-25 07:05:42  	数据分切执行中
# 2022-11-25 07:05:55  	分切数据执行完毕
# 2022-11-25 07:05:57  	模型加载完毕
# 2022-11-25 07:05:57  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 07:12:16  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 07:12:16  Experiment start!
# 2022-11-25 07:12:16  Dataset : tp     interaction : NeuCF
# 2022-11-25 07:12:16  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 07:12:16  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 07:12:16  Round 1 experiment start!
# 2022-11-25 07:12:16  	原始数据集读取完毕
# 2022-11-25 07:12:16  	采用异常值处理
# 2022-11-25 07:12:17  	异常值处理完毕
# 2022-11-25 07:12:17  	Node2Vec 基于用户切割完毕
# 2022-11-25 07:12:17  	数据分切执行中
# 2022-11-25 07:12:29  	分切数据执行完毕
# 2022-11-25 07:12:31  	模型加载完毕
# 2022-11-25 07:12:31  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 07:18:57  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 07:18:57  Experiment start!
# 2022-11-25 07:18:57  Dataset : rt     interaction : CSMF
# 2022-11-25 07:18:57  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 07:18:57  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 07:18:57  Round 1 experiment start!
# 2022-11-25 07:18:57  	原始数据集读取完毕
# 2022-11-25 07:18:57  	采用异常值处理
# 2022-11-25 07:18:58  	异常值处理完毕
# 2022-11-25 07:18:59  	Node2Vec 基于用户切割完毕
# 2022-11-25 07:18:59  	数据分切执行中
# 2022-11-25 07:19:11  	分切数据执行完毕
# 2022-11-25 07:19:13  	模型加载完毕
# 2022-11-25 07:19:13  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 07:28:19  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 07:28:19  Experiment start!
# 2022-11-25 07:28:19  Dataset : tp     interaction : CSMF
# 2022-11-25 07:28:19  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 07:28:19  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 07:28:19  Round 1 experiment start!
# 2022-11-25 07:28:19  	原始数据集读取完毕
# 2022-11-25 07:28:19  	采用异常值处理
# 2022-11-25 07:28:20  	异常值处理完毕
# 2022-11-25 07:28:20  	Node2Vec 基于用户切割完毕
# 2022-11-25 07:28:20  	数据分切执行中
# 2022-11-25 07:28:32  	分切数据执行完毕
# 2022-11-25 07:28:34  	模型加载完毕
# 2022-11-25 07:28:34  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 07:37:28  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 07:37:28  Experiment start!
# 2022-11-25 07:37:28  Dataset : rt     interaction : NeuGraphMF
# 2022-11-25 07:37:28  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 07:37:28  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 07:37:28  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 07:37:28  Round 1 experiment start!
# 2022-11-25 07:37:28  	原始数据集读取完毕
# 2022-11-25 07:37:28  	采用异常值处理
# 2022-11-25 07:37:29  	异常值处理完毕
# 2022-11-25 07:37:29  	Node2Vec 基于用户切割完毕
# 2022-11-25 07:37:29  	数据分切执行中
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 07:50:59  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 07:50:59  Experiment start!
# 2022-11-25 07:50:59  Dataset : tp     interaction : NeuGraphMF
# 2022-11-25 07:50:59  Density : 10.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 07:50:59  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 07:50:59  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 07:50:59  Round 1 experiment start!
# 2022-11-25 07:50:59  	原始数据集读取完毕
# 2022-11-25 07:50:59  	采用异常值处理
# 2022-11-25 07:51:00  	异常值处理完毕
# 2022-11-25 07:51:00  	Node2Vec 基于用户切割完毕
# 2022-11-25 07:51:01  	数据分切执行中
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.15

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 08:05:03  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 08:05:03  Experiment start!
# 2022-11-25 08:05:03  Dataset : rt     interaction : NeuCF
# 2022-11-25 08:05:03  Density : 15.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 08:05:03  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 08:05:03  Round 1 experiment start!
# 2022-11-25 08:05:03  	原始数据集读取完毕
# 2022-11-25 08:05:03  	采用异常值处理
# 2022-11-25 08:05:04  	异常值处理完毕
# 2022-11-25 08:05:04  	Node2Vec 基于用户切割完毕
# 2022-11-25 08:05:04  	数据分切执行中
# 2022-11-25 08:05:16  	分切数据执行完毕
# 2022-11-25 08:05:18  	模型加载完毕
# 2022-11-25 08:05:18  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 08:12:23  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 08:12:23  Experiment start!
# 2022-11-25 08:12:23  Dataset : tp     interaction : NeuCF
# 2022-11-25 08:12:23  Density : 15.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 08:12:23  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 08:12:23  Round 1 experiment start!
# 2022-11-25 08:12:23  	原始数据集读取完毕
# 2022-11-25 08:12:23  	采用异常值处理
# 2022-11-25 08:12:24  	异常值处理完毕
# 2022-11-25 08:12:24  	Node2Vec 基于用户切割完毕
# 2022-11-25 08:12:24  	数据分切执行中
# 2022-11-25 08:12:36  	分切数据执行完毕
# 2022-11-25 08:12:38  	模型加载完毕
# 2022-11-25 08:12:38  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 08:19:37  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 08:19:37  Experiment start!
# 2022-11-25 08:19:37  Dataset : rt     interaction : CSMF
# 2022-11-25 08:19:37  Density : 15.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 08:19:37  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 08:19:37  Round 1 experiment start!
# 2022-11-25 08:19:37  	原始数据集读取完毕
# 2022-11-25 08:19:37  	采用异常值处理
# 2022-11-25 08:19:38  	异常值处理完毕
# 2022-11-25 08:19:38  	Node2Vec 基于用户切割完毕
# 2022-11-25 08:19:38  	数据分切执行中
# 2022-11-25 08:19:51  	分切数据执行完毕
# 2022-11-25 08:19:53  	模型加载完毕
# 2022-11-25 08:19:53  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 08:29:27  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 08:29:27  Experiment start!
# 2022-11-25 08:29:27  Dataset : tp     interaction : CSMF
# 2022-11-25 08:29:27  Density : 15.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 08:29:27  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 08:29:27  Round 1 experiment start!
# 2022-11-25 08:29:27  	原始数据集读取完毕
# 2022-11-25 08:29:27  	采用异常值处理
# 2022-11-25 08:29:28  	异常值处理完毕
# 2022-11-25 08:29:28  	Node2Vec 基于用户切割完毕
# 2022-11-25 08:29:28  	数据分切执行中
# 2022-11-25 08:29:41  	分切数据执行完毕
# 2022-11-25 08:29:43  	模型加载完毕
# 2022-11-25 08:29:43  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 08:39:04  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 08:39:04  Experiment start!
# 2022-11-25 08:39:04  Dataset : rt     interaction : NeuGraphMF
# 2022-11-25 08:39:04  Density : 15.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 08:39:04  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 08:39:04  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 08:39:04  Round 1 experiment start!
# 2022-11-25 08:39:04  	原始数据集读取完毕
# 2022-11-25 08:39:04  	采用异常值处理
# 2022-11-25 08:39:05  	异常值处理完毕
# 2022-11-25 08:39:05  	Node2Vec 基于用户切割完毕
# 2022-11-25 08:39:05  	数据分切执行中
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 08:54:27  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 08:54:27  Experiment start!
# 2022-11-25 08:54:27  Dataset : tp     interaction : NeuGraphMF
# 2022-11-25 08:54:27  Density : 15.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 08:54:27  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 08:54:27  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 08:54:27  Round 1 experiment start!
# 2022-11-25 08:54:27  	原始数据集读取完毕
# 2022-11-25 08:54:27  	采用异常值处理
# 2022-11-25 08:54:28  	异常值处理完毕
# 2022-11-25 08:54:28  	Node2Vec 基于用户切割完毕
# 2022-11-25 08:54:28  	数据分切执行中
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.20

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 1
# Out:
# 2022-11-25 09:09:48  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 09:09:48  Experiment start!
# 2022-11-25 09:09:48  Dataset : rt     interaction : NeuCF
# 2022-11-25 09:09:48  Density : 20.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 09:09:48  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 09:09:48  Round 1 experiment start!
# 2022-11-25 09:09:48  	原始数据集读取完毕
# 2022-11-25 09:09:48  	采用异常值处理
# 2022-11-25 09:09:49  	异常值处理完毕
# 2022-11-25 09:09:49  	Node2Vec 基于用户切割完毕
# 2022-11-25 09:09:49  	数据分切执行中
# 2022-11-25 09:10:01  	分切数据执行完毕
# 2022-11-25 09:10:03  	模型加载完毕
# 2022-11-25 09:10:03  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 1
# Out:
# 2022-11-25 09:17:40  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 09:17:40  Experiment start!
# 2022-11-25 09:17:40  Dataset : tp     interaction : NeuCF
# 2022-11-25 09:17:40  Density : 20.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 09:17:40  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 09:17:40  Round 1 experiment start!
# 2022-11-25 09:17:40  	原始数据集读取完毕
# 2022-11-25 09:17:40  	采用异常值处理
# 2022-11-25 09:17:41  	异常值处理完毕
# 2022-11-25 09:17:41  	Node2Vec 基于用户切割完毕
# 2022-11-25 09:17:41  	数据分切执行中
# 2022-11-25 09:17:54  	分切数据执行完毕
# 2022-11-25 09:17:56  	模型加载完毕
# 2022-11-25 09:17:56  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 1
# Out:
# 2022-11-25 09:25:36  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 09:25:36  Experiment start!
# 2022-11-25 09:25:36  Dataset : rt     interaction : CSMF
# 2022-11-25 09:25:36  Density : 20.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 09:25:36  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 09:25:36  Round 1 experiment start!
# 2022-11-25 09:25:36  	原始数据集读取完毕
# 2022-11-25 09:25:36  	采用异常值处理
# 2022-11-25 09:25:37  	异常值处理完毕
# 2022-11-25 09:25:37  	Node2Vec 基于用户切割完毕
# 2022-11-25 09:25:37  	数据分切执行中
# 2022-11-25 09:25:49  	分切数据执行完毕
# 2022-11-25 09:25:51  	模型加载完毕
# 2022-11-25 09:25:51  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 1
# Out:
# 2022-11-25 09:35:58  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 09:35:58  Experiment start!
# 2022-11-25 09:35:58  Dataset : tp     interaction : CSMF
# 2022-11-25 09:35:58  Density : 20.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 09:35:58  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 09:35:58  Round 1 experiment start!
# 2022-11-25 09:35:58  	原始数据集读取完毕
# 2022-11-25 09:35:58  	采用异常值处理
# 2022-11-25 09:35:59  	异常值处理完毕
# 2022-11-25 09:35:59  	Node2Vec 基于用户切割完毕
# 2022-11-25 09:35:59  	数据分切执行中
# 2022-11-25 09:36:12  	分切数据执行完毕
# 2022-11-25 09:36:14  	模型加载完毕
# 2022-11-25 09:36:14  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 1
# Out:
# 2022-11-25 09:46:16  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 09:46:16  Experiment start!
# 2022-11-25 09:46:16  Dataset : rt     interaction : NeuGraphMF
# 2022-11-25 09:46:16  Density : 20.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 09:46:16  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 09:46:16  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 09:46:16  Round 1 experiment start!
# 2022-11-25 09:46:16  	原始数据集读取完毕
# 2022-11-25 09:46:16  	采用异常值处理
# 2022-11-25 09:46:17  	异常值处理完毕
# 2022-11-25 09:46:17  	Node2Vec 基于用户切割完毕
# 2022-11-25 09:46:17  	数据分切执行中
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 1
# Out:
# 2022-11-25 10:03:31  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.2, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 10:03:31  Experiment start!
# 2022-11-25 10:03:31  Dataset : tp     interaction : NeuGraphMF
# 2022-11-25 10:03:31  Density : 20.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 10:03:31  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 10:03:31  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 10:03:31  Round 1 experiment start!
# 2022-11-25 10:03:32  	原始数据集读取完毕
# 2022-11-25 10:03:32  	采用异常值处理
# 2022-11-25 10:03:33  	异常值处理完毕
# 2022-11-25 10:03:33  	Node2Vec 基于用户切割完毕
# 2022-11-25 10:03:33  	数据分切执行中
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.25

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.25 --slices 10 --part_type 1
# Out:
# 2022-11-25 10:20:13  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 10:20:13  Experiment start!
# 2022-11-25 10:20:13  Dataset : rt     interaction : NeuCF
# 2022-11-25 10:20:13  Density : 25.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 10:20:13  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 10:20:13  Round 1 experiment start!
# 2022-11-25 10:20:13  	原始数据集读取完毕
# 2022-11-25 10:20:13  	采用异常值处理
# 2022-11-25 10:20:14  	异常值处理完毕
# 2022-11-25 10:20:14  	Node2Vec 基于用户切割完毕
# 2022-11-25 10:20:14  	数据分切执行中
# 2022-11-25 10:20:26  	分切数据执行完毕
# 2022-11-25 10:20:28  	模型加载完毕
# 2022-11-25 10:20:28  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.25 --slices 10 --part_type 1
# Out:
# 2022-11-25 10:28:48  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 10:28:48  Experiment start!
# 2022-11-25 10:28:48  Dataset : tp     interaction : NeuCF
# 2022-11-25 10:28:48  Density : 25.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 10:28:48  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 10:28:48  Round 1 experiment start!
# 2022-11-25 10:28:48  	原始数据集读取完毕
# 2022-11-25 10:28:48  	采用异常值处理
# 2022-11-25 10:28:49  	异常值处理完毕
# 2022-11-25 10:28:49  	Node2Vec 基于用户切割完毕
# 2022-11-25 10:28:49  	数据分切执行中
# 2022-11-25 10:29:01  	分切数据执行完毕
# 2022-11-25 10:29:03  	模型加载完毕
# 2022-11-25 10:29:03  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.25 --slices 10 --part_type 1
# Out:
# 2022-11-25 10:37:17  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 10:37:17  Experiment start!
# 2022-11-25 10:37:17  Dataset : rt     interaction : CSMF
# 2022-11-25 10:37:17  Density : 25.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 10:37:17  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 10:37:17  Round 1 experiment start!
# 2022-11-25 10:37:17  	原始数据集读取完毕
# 2022-11-25 10:37:17  	采用异常值处理
# 2022-11-25 10:37:18  	异常值处理完毕
# 2022-11-25 10:37:18  	Node2Vec 基于用户切割完毕
# 2022-11-25 10:37:18  	数据分切执行中
# 2022-11-25 10:37:30  	分切数据执行完毕
# 2022-11-25 10:37:32  	模型加载完毕
# 2022-11-25 10:37:32  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.25 --slices 10 --part_type 1
# Out:
# 2022-11-25 10:48:02  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 10:48:02  Experiment start!
# 2022-11-25 10:48:02  Dataset : tp     interaction : CSMF
# 2022-11-25 10:48:02  Density : 25.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 10:48:02  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 10:48:02  Round 1 experiment start!
# 2022-11-25 10:48:02  	原始数据集读取完毕
# 2022-11-25 10:48:02  	采用异常值处理
# 2022-11-25 10:48:03  	异常值处理完毕
# 2022-11-25 10:48:03  	Node2Vec 基于用户切割完毕
# 2022-11-25 10:48:03  	数据分切执行中
# 2022-11-25 10:48:16  	分切数据执行完毕
# 2022-11-25 10:48:18  	模型加载完毕
# 2022-11-25 10:48:18  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.25 --slices 10 --part_type 1
# Out:
# 2022-11-25 10:58:37  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 10:58:37  Experiment start!
# 2022-11-25 10:58:37  Dataset : rt     interaction : NeuGraphMF
# 2022-11-25 10:58:37  Density : 25.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 10:58:37  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 10:58:37  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 10:58:37  Round 1 experiment start!
# 2022-11-25 10:58:37  	原始数据集读取完毕
# 2022-11-25 10:58:37  	采用异常值处理
# 2022-11-25 10:58:38  	异常值处理完毕
# 2022-11-25 10:58:38  	Node2Vec 基于用户切割完毕
# 2022-11-25 10:58:38  	数据分切执行中
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.25 --slices 10 --part_type 1
# Out:
# 2022-11-25 11:17:34  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.25, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 11:17:34  Experiment start!
# 2022-11-25 11:17:34  Dataset : tp     interaction : NeuGraphMF
# 2022-11-25 11:17:34  Density : 25.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 11:17:34  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 11:17:34  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 11:17:34  Round 1 experiment start!
# 2022-11-25 11:17:34  	原始数据集读取完毕
# 2022-11-25 11:17:34  	采用异常值处理
# 2022-11-25 11:17:35  	异常值处理完毕
# 2022-11-25 11:17:35  	Node2Vec 基于用户切割完毕
# 2022-11-25 11:17:35  	数据分切执行中
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.30

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.30 --slices 10 --part_type 1
# Out:
# 2022-11-25 11:35:42  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 11:35:42  Experiment start!
# 2022-11-25 11:35:42  Dataset : rt     interaction : NeuCF
# 2022-11-25 11:35:42  Density : 30.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 11:35:42  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 11:35:42  Round 1 experiment start!
# 2022-11-25 11:35:42  	原始数据集读取完毕
# 2022-11-25 11:35:43  	采用异常值处理
# 2022-11-25 11:35:43  	异常值处理完毕
# 2022-11-25 11:35:43  	Node2Vec 基于用户切割完毕
# 2022-11-25 11:35:44  	数据分切执行中
# 2022-11-25 11:35:54  	分切数据执行完毕
# 2022-11-25 11:35:56  	模型加载完毕
# 2022-11-25 11:35:56  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.30 --slices 10 --part_type 1
# Out:
# 2022-11-25 11:45:04  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 11:45:04  Experiment start!
# 2022-11-25 11:45:04  Dataset : tp     interaction : NeuCF
# 2022-11-25 11:45:04  Density : 30.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 11:45:04  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 11:45:04  Round 1 experiment start!
# 2022-11-25 11:45:04  	原始数据集读取完毕
# 2022-11-25 11:45:04  	采用异常值处理
# 2022-11-25 11:45:05  	异常值处理完毕
# 2022-11-25 11:45:06  	Node2Vec 基于用户切割完毕
# 2022-11-25 11:45:06  	数据分切执行中
# 2022-11-25 11:45:17  	分切数据执行完毕
# 2022-11-25 11:45:19  	模型加载完毕
# 2022-11-25 11:45:19  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.30 --slices 10 --part_type 1
# Out:
# 2022-11-25 12:04:16  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 12:04:16  Experiment start!
# 2022-11-25 12:04:16  Dataset : rt     interaction : CSMF
# 2022-11-25 12:04:16  Density : 30.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 12:04:16  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 12:04:16  Round 1 experiment start!
# 2022-11-25 12:04:16  	原始数据集读取完毕
# 2022-11-25 12:04:16  	采用异常值处理
# 2022-11-25 12:04:17  	异常值处理完毕
# 2022-11-25 12:04:17  	Node2Vec 基于用户切割完毕
# 2022-11-25 12:04:17  	数据分切执行中
# 2022-11-25 12:04:29  	分切数据执行完毕
# 2022-11-25 12:04:31  	模型加载完毕
# 2022-11-25 12:04:31  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.30 --slices 10 --part_type 1
# Out:
# 2022-11-25 12:16:10  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 12:16:10  Experiment start!
# 2022-11-25 12:16:10  Dataset : tp     interaction : CSMF
# 2022-11-25 12:16:10  Density : 30.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 12:16:10  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 12:16:10  Round 1 experiment start!
# 2022-11-25 12:16:10  	原始数据集读取完毕
# 2022-11-25 12:16:10  	采用异常值处理
# 2022-11-25 12:16:11  	异常值处理完毕
# 2022-11-25 12:16:11  	Node2Vec 基于用户切割完毕
# 2022-11-25 12:16:12  	数据分切执行中
# 2022-11-25 12:16:23  	分切数据执行完毕
# 2022-11-25 12:16:25  	模型加载完毕
# 2022-11-25 12:16:25  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.30 --slices 10 --part_type 1
# Out:
# 2022-11-25 12:27:45  Namespace(agg_epochs=10, batch_size=128, dataset='rt', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 12:27:45  Experiment start!
# 2022-11-25 12:27:45  Dataset : rt     interaction : NeuGraphMF
# 2022-11-25 12:27:45  Density : 30.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 12:27:45  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 12:27:45  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 12:27:45  Round 1 experiment start!
# 2022-11-25 12:27:45  	原始数据集读取完毕
# 2022-11-25 12:27:45  	采用异常值处理
# 2022-11-25 12:27:46  	异常值处理完毕
# 2022-11-25 12:27:46  	Node2Vec 基于用户切割完毕
# 2022-11-25 12:27:46  	数据分切执行中
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.30 --slices 10 --part_type 1
# Out:
# 2022-11-25 12:49:06  Namespace(agg_epochs=10, batch_size=128, dataset='tp', density=0.3, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 12:49:06  Experiment start!
# 2022-11-25 12:49:06  Dataset : tp     interaction : NeuGraphMF
# 2022-11-25 12:49:06  Density : 30.00%, slice_epochs : 20, agg_epochs : 10
# 2022-11-25 12:49:06  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 12:49:06  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 12:49:06  Round 1 experiment start!
# 2022-11-25 12:49:06  	原始数据集读取完毕
# 2022-11-25 12:49:06  	采用异常值处理
# 2022-11-25 12:49:07  	异常值处理完毕
# 2022-11-25 12:49:07  	Node2Vec 基于用户切割完毕
# 2022-11-25 12:49:07  	数据分切执行中
# ...

# %% [markdown]
# *****

# %% [markdown]
# # RecEarser 实验3

# %% [markdown]
# # Density : 0.10

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 13:10:11  Namespace(agg_epochs=5, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 13:10:11  Experiment start!
# 2022-11-25 13:10:11  Dataset : rt     interaction : NeuCF
# 2022-11-25 13:10:11  Density : 10.00%, slice_epochs : 20, agg_epochs : 5
# 2022-11-25 13:10:11  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 13:10:11  Round 1 experiment start!
# 2022-11-25 13:10:11  	原始数据集读取完毕
# 2022-11-25 13:10:11  	采用异常值处理
# 2022-11-25 13:10:12  	异常值处理完毕
# 2022-11-25 13:10:12  	Node2Vec 基于用户切割完毕
# 2022-11-25 13:10:12  	数据分切执行中
# 2022-11-25 13:10:25  	分切数据执行完毕
# 2022-11-25 13:10:27  	模型加载完毕
# 2022-11-25 13:10:27  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 13:16:14  Namespace(agg_epochs=5, batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='NeuCF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 13:16:14  Experiment start!
# 2022-11-25 13:16:14  Dataset : tp     interaction : NeuCF
# 2022-11-25 13:16:14  Density : 10.00%, slice_epochs : 20, agg_epochs : 5
# 2022-11-25 13:16:14  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 13:16:14  Round 1 experiment start!
# 2022-11-25 13:16:15  	原始数据集读取完毕
# 2022-11-25 13:16:15  	采用异常值处理
# 2022-11-25 13:16:16  	异常值处理完毕
# 2022-11-25 13:16:16  	Node2Vec 基于用户切割完毕
# 2022-11-25 13:16:16  	数据分切执行中
# 2022-11-25 13:16:28  	分切数据执行完毕
# 2022-11-25 13:16:30  	模型加载完毕
# 2022-11-25 13:16:30  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 5 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 13:22:08  Namespace(agg_epochs=5, batch_size=128, dataset='rt', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 13:22:08  Experiment start!
# 2022-11-25 13:22:08  Dataset : rt     interaction : CSMF
# 2022-11-25 13:22:08  Density : 10.00%, slice_epochs : 10, agg_epochs : 5
# 2022-11-25 13:22:08  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 13:22:08  Round 1 experiment start!
# 2022-11-25 13:22:08  	原始数据集读取完毕
# 2022-11-25 13:22:08  	采用异常值处理
# 2022-11-25 13:22:09  	异常值处理完毕
# 2022-11-25 13:22:09  	Node2Vec 基于用户切割完毕
# 2022-11-25 13:22:09  	数据分切执行中
# 2022-11-25 13:22:22  	分切数据执行完毕
# 2022-11-25 13:22:24  	模型加载完毕
# 2022-11-25 13:22:24  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 5 --density 0.10 --slices 10 --part_type 1
# Out:
# 2022-11-25 13:28:11  Namespace(agg_epochs=5, batch_size=128, dataset='tp', density=0.1, devices='gpu', dimension=64, dropout=0.1, interaction='CSMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=10, slices=10, verbose=0)
# 2022-11-25 13:28:11  Experiment start!
# 2022-11-25 13:28:11  Dataset : tp     interaction : CSMF
# 2022-11-25 13:28:11  Density : 10.00%, slice_epochs : 10, agg_epochs : 5
# 2022-11-25 13:28:11  Part_type : 1,    slices : 10,       devices : gpu
#
# 2022-11-25 13:28:11  Round 1 experiment start!
# 2022-11-25 13:28:11  	原始数据集读取完毕
# 2022-11-25 13:28:11  	采用异常值处理
# 2022-11-25 13:28:12  	异常值处理完毕
# 2022-11-25 13:28:12  	Node2Vec 基于用户切割完毕
# 2022-11-25 13:28:12  	数据分切执行中
# 2022-11-25 13:28:25  	分切数据执行完毕
# 2022-11-25 13:28:27  	模型加载完毕
# 2022-11-25 13:28:27  	准备训练切片模型
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.10 --slices 10 --part_type 1
# Out:
# ^C
# Traceback (most recent call last):
#   File "Experiment.py", line 5, in <module>
#     from utility.early_stop import EarlyStopping
#   File "/home/yxzeng/code_python/RecEraser_GPU_NeuCF_GraphMF_CSMF/utility/early_stop.py", line 2, in <module>
#     import torch as t
#   File "/home/yxzeng/anaconda3/lib/python3.8/site-packages/torch/__init__.py", line 197, in <module>
#     from torch._C import *  # noqa: F403
# RuntimeError: KeyboardInterrupt:

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.10 --slices 10 --part_type 1
# Out:
# ^C
# Traceback (most recent call last):
#   File "Experiment.py", line 7, in <module>
#     from models.eraser import TensorEraser
#   File "/home/yxzeng/code_python/RecEraser_GPU_NeuCF_GraphMF_CSMF/models/eraser.py", line 7, in <module>
#     from datasets.dataset import create_graph
#   File "/home/yxzeng/code_python/RecEraser_GPU_NeuCF_GraphMF_CSMF/datasets/dataset.py", line 7, in <module>
#     from node2vec import Node2Vec
#   File "/home/yxzeng/anaconda3/lib/python3.8/site-packages/node2vec/__init__.py", line 2, in <module>
#     from .node2vec import Node2Vec
#   File "/home/yxzeng/anaconda3/lib/python3.8/site-packages/node2vec/node2vec.py", line 6, in <module>
#     import networkx as nx
#   File "/home/yxzeng/anaconda3/lib/python3.8/site-packages/networkx/__init__.py", line 61, in <module>
#     import networkx.generators
#   File "/home/yxzeng/anaconda3/lib/python3.8/site-packages/networkx/generators/__init__.py", line 16, in <module>
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.15

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.15 --slices 10 --part_type 1
# Out:
# ^C
# Traceback (most recent call last):
#   File "Experiment.py", line 5, in <module>
#     from utility.early_stop import EarlyStopping
#   File "/home/yxzeng/code_python/RecEraser_GPU_NeuCF_GraphMF_CSMF/utility/early_stop.py", line 2, in <module>
#     import torch as t
#   File "/home/yxzeng/anaconda3/lib/python3.8/site-packages/torch/__init__.py", line 197, in <module>
#     from torch._C import *  # noqa: F403
# RuntimeError: KeyboardInterrupt:

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.15 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 5 --density 0.15 --slices 10 --part_type 1
# Out:
# ^C
# Traceback (most recent call last):
#   File "Experiment.py", line 5, in <module>
#     from utility.early_stop import EarlyStopping
#   File "/home/yxzeng/code_python/RecEraser_GPU_NeuCF_GraphMF_CSMF/utility/early_stop.py", line 2, in <module>
#     import torch as t
#   File "/home/yxzeng/anaconda3/lib/python3.8/site-packages/torch/__init__.py", line 197, in <module>
#     from torch._C import *  # noqa: F403
# RuntimeError: KeyboardInterrupt:

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 5 --density 0.15 --slices 10 --part_type 1
# Out:
# ^C
# Traceback (most recent call last):
#   File "Experiment.py", line 5, in <module>
#     from utility.early_stop import EarlyStopping
#   File "/home/yxzeng/code_python/RecEraser_GPU_NeuCF_GraphMF_CSMF/utility/early_stop.py", line 2, in <module>
#     import torch as t
#   File "/home/yxzeng/anaconda3/lib/python3.8/site-packages/torch/__init__.py", line 197, in <module>
#     from torch._C import *  # noqa: F403
# RuntimeError: KeyboardInterrupt:

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.15 --slices 10 --part_type 1
# Out:
# ^C
# Traceback (most recent call last):
#   File "Experiment.py", line 5, in <module>
#     from utility.early_stop import EarlyStopping
#   File "/home/yxzeng/code_python/RecEraser_GPU_NeuCF_GraphMF_CSMF/utility/early_stop.py", line 2, in <module>
#     import torch as t
#   File "/home/yxzeng/anaconda3/lib/python3.8/site-packages/torch/__init__.py", line 197, in <module>
#     from torch._C import *  # noqa: F403
# RuntimeError: KeyboardInterrupt:

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.15 --slices 10 --part_type 1
# Out:
# 2022-11-25 13:28:45  Namespace(agg_epochs=5, batch_size=128, dataset='tp', density=0.15, devices='gpu', dimension=64, dropout=0.1, interaction='NeuGraphMF', node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=1000, node2vec_length=10, node2vec_walk=50, num_layers=2, order=2, part_type=1, path='./datasets/data/WSDREAM/', processed=1, retrain=0, rounds=1, save_model=1, slice_epochs=20, slices=10, verbose=0)
# 2022-11-25 13:28:45  Experiment start!
# 2022-11-25 13:28:45  Dataset : tp     interaction : NeuGraphMF
# 2022-11-25 13:28:45  Density : 15.00%, slice_epochs : 20, agg_epochs : 5
# 2022-11-25 13:28:45  Part_type : 1,    slices : 10,       devices : gpu
# 2022-11-25 13:28:45  Evaluating : NeuGraphMF - Dim : 64 - Order : 2
#
# 2022-11-25 13:28:45  Round 1 experiment start!
# 2022-11-25 13:28:45  	原始数据集读取完毕
# 2022-11-25 13:28:45  	采用异常值处理
# 2022-11-25 13:28:46  	异常值处理完毕
# 2022-11-25 13:28:46  	Node2Vec 基于用户切割完毕
# 2022-11-25 13:28:46  	数据分切执行中
# ...

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.20

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.20 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.20 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 5 --density 0.20 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 5 --density 0.20 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.20 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.20 --slices 10 --part_type 1

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.25

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.25 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.25 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 5 --density 0.25 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 5 --density 0.25 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.25 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.25 --slices 10 --part_type 1

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.30

# %% [markdown]
# ### Eraser

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.30 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.30 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 5 --density 0.30 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 10 --agg_epochs 5 --density 0.30 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.30 --slices 10 --part_type 1

# %%
# !python Experiment.py --dataset tp --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 5 --density 0.30 --slices 10 --part_type 1

# %% [markdown]
# *****

# %% [markdown]
# # Density : 0.10

# %% [markdown]
# ### SISA2

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.10 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.10 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 20 --agg_epochs 15 --density 0.10 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.10 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.10 --slices 10 --part_type 2 --save_model 1 --processed 1

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.15

# %% [markdown]
# ### SISA2

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.15 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.15 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.15 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.15 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.15 --slices 10 --part_type 2 --save_model 1 --processed 1

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.20

# %% [markdown]
# ### SISA2

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.20 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.20 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.20 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.20 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.20 --slices 10 --part_type 2 --save_model 1 --processed 1

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.25

# %% [markdown]
# ### SISA2

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.25 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.25 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.25 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.25 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.25 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.25 --slices 10 --part_type 2 --save_model 1 --processed 1

# %% [markdown]
# *****

# %% [markdown]
# ## Density : 0.30

# %% [markdown]
# ### SISA2

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.30 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slice_epochs 25 --agg_epochs 10 --density 0.30 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.30 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slice_epochs 25 --agg_epochs 15 --density 0.30 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.30 --slices 10 --part_type 2 --save_model 1 --processed 1

# %%
# !python Experiment.py --dataset rt --interaction NeuGraphMF --rounds 1 --slice_epochs 20 --agg_epochs 10 --density 0.30 --slices 10 --part_type 2 --save_model 1 --processed 1
