# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(2,26,2)
y = np.array([15,13,14.5,17,20,25,26,26,27,22,18,15])

# %%
x_min, x_max = 2, 25
y_min, y_max = 0, 30
x_interval = 5
y_interval = 5

# 绘图
plt.figure(figsize=(9, 6), dpi=200)
plt.plot(x, y, color = 'r', marker = "s", markersize=7, markerfacecolor="red", label='Bar_1')
plt.plot(x, y - 4, color = 'b', marker = "s", markersize=7, markerfacecolor="blue", label='Bar_1')

# plt.legend(loc = 10)
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
plt.xlim(x_min - 1, x_max + 1)
plt.ylim(y_min - 1, y_max + 1)
plt.grid()
plt.xticks(np.linspace(x_min, x_max, x_interval))
plt.yticks(np.linspace(y_min, y_max, y_interval))
plt.xlabel('asd')
plt.ylabel('Error')
num1=0.435
num2=1
num3=3
num4=0.5
plt.legend(bbox_to_anchor=(num1, num2), loc=num3, borderaxespad=num4)
# 显示
plt.show()
plt.savefig('output',bbox_inches='tight', pad_inches=0.0)

# %%
# 切割方式
import matplotlib.pyplot as plt
import numpy as np

# 输入统计数据
plt.figure(figsize=(9, 6), dpi=200)

index = ('NeuCF', 'CSMF', 'Basic MF', 'GraphMF')

buy_number_male = [6, 7, 6, 1]
buy_number_female = [9, 4, 4, 5]
buy_number_female2 = [9, 4, 4, 5]
buy_number_female3 = [9, 4, 4, 5]

bar_width = 0.15  # 条形宽度
Idx1 = np.arange(len(index)) # --rounds 2
Idx2 = Idx1 + bar_width + 0.05
Idx3 = Idx1 + bar_width * 2 + 0.10
Idx4 = Idx1 + bar_width * 3 + 0.15

# 使用两次 bar 函数画出两组条形图
plt.bar(Idx1, height=buy_number_male, width=bar_width, color='#1f77b4', edgecolor = 'black', label='NeuCF')
plt.bar(Idx2, height=buy_number_female, width=bar_width, color='#2ca02c', edgecolor = 'black', label='CSMF')
plt.bar(Idx3, height=buy_number_female2, width=bar_width, color='#ff7f0e', edgecolor = 'black', label='Basic MF')
plt.bar(Idx4, height=buy_number_female3, width=bar_width, color='#d62728', edgecolor = 'black', label='GraphMF')

plt.legend()  # 显示图例
plt.xticks((Idx1 + Idx4) / 2, index)
plt.ylabel('qwe')  # 纵坐标轴标题
plt.title('asd')  # 图形标题
plt.xlim([-0.2, 3.8])

plt.show()

# %%
# 聚合方式
import matplotlib.pyplot as plt
import numpy as np

# 输入统计数据
plt.figure(figsize=(9, 6), dpi=200)

index = ('NeuCF', 'CSMF', 'Basic MF', 'GraphMF')
# Results
buy_number_male = [6, 7, 6, 1]
buy_number_female = [9, 4, 4, 5]
buy_number_female2 = [9, 4, 4, 5]
buy_number_female3 = [9, 4, 4, 5]

bar_width = 0.15  # 条形宽度
Idx1 = np.arange(len(index)) # 男生条形图的横坐标
Idx2 = Idx1 + bar_width + 0.05
Idx3 = Idx1 + bar_width * 2 + 0.10
Idx4 = Idx1 + bar_width * 3 + 0.15

# 使用两次 bar 函数画出两组条形图
plt.bar(Idx1, height=buy_number_male, width=bar_width, color='#4C72B0', edgecolor = 'black', label='User-random-based')
plt.bar(Idx2, height=buy_number_female, width=bar_width, color='#DD8452', edgecolor = 'black', label='User-region-based')
plt.bar(Idx3, height=buy_number_female2, width=bar_width, color='#55A868', edgecolor = 'black', label='Item-based')
plt.bar(Idx4, height=buy_number_female3, width=bar_width, color='#C44E52', edgecolor = 'black', label='User-based')

plt.legend()  # 显示图例
plt.xticks((Idx1 + Idx4) / 2, index)
plt.ylabel('qwe')  # 纵坐标轴标题
plt.title('asd')  # 图形标题
plt.xlim([-0.2, 3.8])

plt.show()

# %%
# shards number
import matplotlib.pyplot as plt
import numpy as np

# 输入统计数据
plt.figure(figsize=(9, 6), dpi=200)
index = ('NeuCF', 'CSMF', 'Basic MF', 'GraphMF')
buy_number_male = [6, 7, 6, 1]
buy_number_female = [9, 4, 4, 5]
buy_number_female2 = [9, 4, 4, 5]
buy_number_female3 = [9, 4, 4, 5]

bar_width = 0.15  # 条形宽度
Idx1 = np.arange(len(index))
Idx2 = Idx1 + bar_width + 0.05
Idx3 = Idx1 + bar_width * 2 + 0.10
Idx4 = Idx1 + bar_width * 3 + 0.15

# 使用两次 bar 函数画出两组条形图
plt.bar(Idx1, height=buy_number_male, width=bar_width, color='#377EB8', edgecolor = 'black', label='Mean')
plt.bar(Idx2, height=buy_number_female, width=bar_width, color='#FF7F00', edgecolor = 'black', label='Adaptive')
plt.bar(Idx3, height=buy_number_female2, width=bar_width, color='#4DAF4A', edgecolor = 'black', label='Self-attention')
plt.bar(Idx4, height=buy_number_female3, width=bar_width, color='#984EA3', edgecolor = 'black', label='External-attention')

plt.legend()  # 显示图例
plt.xticks((Idx1 + Idx4) / 2, index)
plt.ylabel('qwe')  # 纵坐标轴标题
plt.title('asd')  # 图形标题
plt.xlim([-0.2, 3.8])

plt.show()

# %%
# shards number
import matplotlib.pyplot as plt
import numpy as np

# 输入统计数据
fig, ax1 = plt.subplots()
plt.figure(figsize=(9, 6), dpi=200)

waters = ('a', 'b', 'c', 'd')
buy_number_male = [6, 7, 6, 1]
buy_number_female = [9, 4, 4, 5]
buy_number_female2 = [9, 4, 4, 5]
buy_number_female3 = [9, 4, 4, 5]

bar_width = 0.15  # 条形宽度
Idx1 = np.arange(len(waters))
Idx2 = Idx1 + bar_width + 0.05
Idx3 = Idx1 + bar_width * 2 + 0.10
Idx4 = Idx1 + bar_width * 3 + 0.15

# 使用两次 bar 函数画出两组条形图
ax1.bar(Idx1, height=buy_number_male, width=bar_width, color='#1f77b4', edgecolor = 'black', label='NeuCF')
ax1.bar(Idx2, height=buy_number_female, width=bar_width, color='#2ca02c', edgecolor = 'black', label='CSMF')
ax1.bar(Idx3, height=buy_number_female2, width=bar_width, color='#ff7f0e', edgecolor = 'black', label='Basic MF')
ax1.bar(Idx4, height=buy_number_female3, width=bar_width, color='#d62728', edgecolor = 'black', label='GraphMF')

ax1.legend()  # 显示图例
ax1.set_xticks((Idx1 + Idx4) / 2, waters)
ax1.set_ylabel('qwe')  # 纵坐标轴标题
ax1.set_title('asd')  # 图形标题
ax1.set_xlim([-0.2, 3.8])

ax2 = ax1.twinx()
x = np.array((Idx1 + Idx4) / 2)
y = np.array([15,13,14.5,17])
ax2.plot(x, y, marker = "s", color='#1f77b4')
ax2.plot(x, y - 1, marker = "s", color='#2ca02c')
ax2.plot(x, y - 2, marker = "s", color='#ff7f0e')
ax2.plot(x, y - 3, marker = "s", color='#d62728')
ax2.set_ylabel('Y2', color='C1')
ax2.tick_params(axis='y', labelcolor='C1')
# plt.plot(x, y, color = 'r', marker = "s", markersize=7, markerfacecolor="red", label='Bar_1')
plt.show()
