# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 2 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-27 13:50:07  Experiment start!
# 2023-02-27 13:50:07  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=10, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 2 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-27 14:44:53  Experiment start!
# 2023-02-27 14:44:53  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=10, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 2 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --slices 15 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-27 15:56:55  Experiment start!
# 2023-02-27 15:56:55  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=15, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=15, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 2 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --slices 15 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-27 16:50:49  Experiment start!
# 2023-02-27 16:50:49  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=15, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=15, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 2 --slices 5 --agg_epochs 25 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-27 17:56:40  Experiment start!
# 2023-02-27 17:56:40  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=25, agg_function=1, agg_lr=0.004, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.008, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 2 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-27 18:23:45  Experiment start!
# 2023-02-27 18:23:45  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 2 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-27 19:16:14  Experiment start!
# 2023-02-27 19:16:14  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.004, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 2 --slices 5 --agg_epochs 30 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-27 20:03:39  Experiment start!
# 2023-02-27 20:03:39  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=30, agg_function=1, agg_lr=0.008, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.01, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 2 --slices 5 --agg_epochs 30 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-27 20:54:07  Experiment start!
# 2023-02-27 20:54:07  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=30, agg_function=1, agg_lr=0.004, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.008, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 2 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-27 22:40:18  Experiment start!
# 2023-02-27 22:40:18  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 2 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --agg_type mean --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 00:22:35  Experiment start!
# 2023-02-28 00:22:35  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='mean', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 2 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --agg_type mean --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 01:10:22  Experiment start!
# 2023-02-28 01:10:22  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='mean', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --agg_type softmax --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 02:18:53  Experiment start!
# 2023-02-28 02:18:53  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='softmax', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --agg_type softmax --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 02:41:31  Experiment start!
# 2023-02-28 02:41:31  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='softmax', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slices 5 --agg_epochs 12 --density 0.20 --part_type 5 --agg_type att2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 03:14:15  Experiment start!
# 2023-02-28 03:14:15  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=12, agg_function=1, agg_lr=0.001, agg_type='att2', att_decay=0.01, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.004, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slices 5 --agg_epochs 25 --density 0.20 --part_type 5 --agg_type att2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 03:25:50  Experiment start!
# 2023-02-28 03:25:50  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=25, agg_function=1, agg_lr=0.008, agg_type='att2', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.01, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 1 --slices 5 --agg_epochs 25 --density 0.20 --part_type 5 --agg_type att2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 03:34:38  Experiment start!
# 2023-02-28 03:34:38  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=25, agg_function=1, agg_lr=0.004, agg_type='att2', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --agg_type att2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 03:45:16  Experiment start!
# 2023-02-28 03:45:16  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att2', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slices 5 --agg_epochs 15 --density 0.20 --part_type 5 --agg_type att2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 04:08:04  Experiment start!
# 2023-02-28 04:08:04  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att2', att_decay=0.01, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.004, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slices 5 --agg_epochs 30 --density 0.20 --part_type 5 --agg_type att2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 04:21:36  Experiment start!
# 2023-02-28 04:21:36  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=30, agg_function=1, agg_lr=0.008, agg_type='att2', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.01, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 1 --slices 5 --agg_epochs 30 --density 0.20 --part_type 5 --agg_type att2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 04:33:57  Experiment start!
# 2023-02-28 04:33:57  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=30, agg_function=1, agg_lr=0.004, agg_type='att2', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 50 --density 0.20 --part_type 5 --agg_type att2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 04:45:41  Experiment start!
# 2023-02-28 04:45:41  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=50, agg_function=1, agg_lr=0.001, agg_type='att2', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slices 5 --agg_epochs 12 --density 0.20 --part_type 2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 05:13:41  Experiment start!
# 2023-02-28 05:13:41  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=12, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=2, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.004, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slices 5 --agg_epochs 25 --density 0.20 --part_type 2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 05:24:57  Experiment start!
# 2023-02-28 05:24:57  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=25, agg_function=1, agg_lr=0.008, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=2, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.01, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 1 --slices 5 --agg_epochs 25 --density 0.20 --part_type 2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 05:33:50  Experiment start!
# 2023-02-28 05:33:50  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=25, agg_function=1, agg_lr=0.004, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=20, part_type=2, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 12 --density 0.20 --part_type 2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 05:44:18  Experiment start!
# 2023-02-28 05:44:18  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=12, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=2, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slices 5 --agg_epochs 15 --density 0.20 --part_type 2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 06:02:46  Experiment start!
# 2023-02-28 06:02:46  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=2, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.004, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slices 5 --agg_epochs 30 --density 0.20 --part_type 2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 06:15:41  Experiment start!
# 2023-02-28 06:15:41  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=30, agg_function=1, agg_lr=0.008, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=2, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.01, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 1 --slices 5 --agg_epochs 30 --density 0.20 --part_type 2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 06:27:27  Experiment start!
# 2023-02-28 06:27:27  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=30, agg_function=1, agg_lr=0.004, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=20, part_type=2, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 15 --density 0.20 --part_type 2 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 06:38:58  Experiment start!
# 2023-02-28 06:38:58  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=2, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 12 --density 0.20 --part_type 6 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 06:59:11  Experiment start!
# 2023-02-28 06:59:11  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=12, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=6, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 15 --density 0.20 --part_type 6 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 07:01:02  Experiment start!
# 2023-02-28 07:01:02  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=6, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 12 --density 0.20 --part_type 8 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 07:03:06  Experiment start!
# 2023-02-28 07:03:06  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=12, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=8, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 5 --agg_epochs 15 --density 0.20 --part_type 8 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-02-28 07:20:03  Experiment start!
# 2023-02-28 07:20:03  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=15, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=5, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=8, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=5, verbose=0, wd=0.0005)
# ...
