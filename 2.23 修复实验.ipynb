# %%
# !python Retrain_speed.py --dataset tp --rounds 1 --density 0.20 --record 0
# Out:
# 2023-03-01 05:07:57  Experiment start!
# 2023-03-01 05:07:57  Namespace(agg_epochs=100, batch_size=128, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dropout=0.1, ex='performance', interaction='NeuCF', num_layers=2, order=2, part_type=10, path='./datasets/data/WSDREAM/', processed=0, random_state=1001, record=0, retrain=1, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=1, speed=[50, 30, 50, 30], speed2=[50, 30, 60, 40], verbose=1)
# ...
# 100%|███████████████████████████████████████████| 30/30 [11:49<00:00, 23.64s/it]
# rt-----Inference Time: NeuCF-351.82s
# rt-----Inference Time: CSMF-330.80s
# rt-----Inference Time: MF-188.78s
# rt-----Inference Time: GraphMF-709.31s
# ...
# 100%|███████████████████████████████████████████| 40/40 [15:47<00:00, 23.69s/it]
# tp-----Inference Time: NeuCF-354.80s
# tp-----Inference Time: CSMF-329.90s
# tp-----Inference Time: MF-228.92s
# tp-----Inference Time: GraphMF-947.53s
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 3 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 01:06:55  Experiment start!
# 2023-03-02 01:06:55  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=3, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.004, slices=10, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 3 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 01:53:17  Experiment start!
# 2023-03-02 01:53:17  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.008, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=3, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.01, slices=10, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 3 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 02:24:49  Experiment start!
# 2023-03-02 02:24:49  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.004, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=3, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.008, slices=10, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 3 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 02:51:54  Experiment start!
# 2023-03-02 02:51:54  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=3, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=10, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 3 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 03:50:47  Experiment start!
# 2023-03-02 03:50:47  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=3, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.004, slices=10, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 3 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 04:38:50  Experiment start!
# 2023-03-02 04:38:50  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.008, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=3, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.01, slices=10, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 3 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 05:22:11  Experiment start!
# 2023-03-02 05:22:11  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.004, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=3, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.008, slices=10, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 3 --slices 10 --agg_epochs 60 --density 0.20 --part_type 5 --slices 10 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 05:53:45  Experiment start!
# 2023-03-02 05:53:45  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=3, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=10, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slices 15 --agg_epochs 60 --density 0.20 --part_type 5 --slices 15 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 07:48:38  Experiment start!
# 2023-03-02 07:48:38  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=15, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.004, slices=15, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slices 15 --agg_epochs 60 --density 0.20 --part_type 5 --slices 15 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 08:10:14  Experiment start!
# 2023-03-02 08:10:14  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.008, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=15, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.01, slices=15, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 1 --slices 15 --agg_epochs 60 --density 0.20 --part_type 5 --slices 15 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 08:30:13  Experiment start!
# 2023-03-02 08:30:13  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.004, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=15, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.008, slices=15, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --slices 15 --agg_epochs 60 --density 0.20 --part_type 5 --slices 15 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 08:45:34  Experiment start!
# 2023-03-02 08:45:34  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=15, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=15, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slices 15 --agg_epochs 60 --density 0.20 --part_type 5 --slices 15 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 09:12:21  Experiment start!
# 2023-03-02 09:12:21  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=15, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.004, slices=15, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slices 15 --agg_epochs 60 --density 0.20 --part_type 5 --slices 15 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 09:38:45  Experiment start!
# 2023-03-02 09:38:45  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.008, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=15, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.01, slices=15, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 1 --slices 15 --agg_epochs 60 --density 0.20 --part_type 5 --slices 15 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 09:59:41  Experiment start!
# 2023-03-02 09:59:41  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.004, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=15, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.008, slices=15, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 15 --agg_epochs 60 --density 0.20 --part_type 5 --slices 15 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 10:11:47  Experiment start!
# 2023-03-02 10:11:47  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=15, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=15, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction NeuCF --rounds 1 --slices 20 --agg_epochs 60 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 10:52:51  Experiment start!
# 2023-03-02 10:52:51  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.004, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction CSMF --rounds 1 --slices 20 --agg_epochs 60 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 11:24:27  Experiment start!
# 2023-03-02 11:24:27  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.008, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.01, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction MF --rounds 1 --slices 20 --agg_epochs 60 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 11:53:15  Experiment start!
# 2023-03-02 11:53:15  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.004, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.008, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset rt --interaction GraphMF --rounds 1 --slices 20 --agg_epochs 60 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 12:05:52  Experiment start!
# 2023-03-02 12:05:52  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction NeuCF --rounds 1 --slices 20 --agg_epochs 60 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 12:31:13  Experiment start!
# 2023-03-02 12:31:13  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=64, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.004, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction CSMF --rounds 1 --slices 20 --agg_epochs 60 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 12:57:28  Experiment start!
# 2023-03-02 12:57:28  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.008, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='CSMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.01, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction MF --rounds 1 --slices 20 --agg_epochs 60 --density 0.20 --part_type 5 --slices 20 --record 0 --ex Ablation --verbose 0
# Out:
# 2023-03-02 13:20:25  Experiment start!
# 2023-03-02 13:20:25  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.004, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='MF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=0, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.008, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment.py --dataset tp --interaction GraphMF --rounds 1 --slices 20 --agg_epochs 60 --density 0.20 --part_type 5 --slices 20 --record 0  --ex Ablation --verbose 0
# Out:
# 2023-03-02 13:34:17  Experiment start!
# 2023-03-02 13:34:17  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=60, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.01, att_lr=0.01, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='tp', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='Ablation', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='GraphMF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=20, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=80, slice_lr=0.008, slices=20, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment_speed.py --rounds 3 --density 0.20 --record 0 --verbose 0
# Out:
# 2023-03-05 04:47:04  Experiment start!
# 2023-03-05 04:47:04  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='performance', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=3, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=0, wd=0.0005)
# 22 23 27 33 33 35 50 37 45 34
# ...

# %%
# !python Experiment_speed.py --rounds 3 --density 0.20 --record 0 --verbose 0
# Out:
# 2023-03-05 17:27:40  Experiment start!
# 2023-03-05 17:27:40  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='performance', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=3, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=0, wd=0.0005)
# ...

# %%
# !python Experiment_speed.py --rounds 1 --density 0.20 --record 0 --verbose 0
# Out:
# 2023-03-10 22:13:51  Experiment start!
# 2023-03-10 22:13:51  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='performance', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=0, wd=0.0005)
# 65 76 69 67 62
# ...

# %%
# !python Experiment_speed.py --rounds 2 --density 0.20 --record 0 --verbose 0
# Out:
# 2023-03-11 03:11:28  Experiment start!
# 2023-03-11 03:11:28  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='performance', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=0, wd=0.0005)
# 65 76 69 67 62
# ...

# %%
# !python Experiment_speed.py --rounds 2 --density 0.20 --record 0 --verbose 0  # CSMF MF
# Out:
# 2023-03-11 15:44:35  Experiment start!
# 2023-03-11 15:44:35  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='performance', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=0, wd=0.0005)
# 65 76 69 67 62
# ...

# %%
# !python Experiment_speed.py --rounds 2 --density 0.20 --record 0 --verbose 0  # NCF & GraphMF
# Out:
# 2023-03-12 02:06:39  Experiment start!
# 2023-03-12 02:06:39  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='performance', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=2, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=0, wd=0.0005)
# 65 76 69 67 62
# ...

# %%
# !python Experiment_speed.py --rounds 1 --density 0.20 --record 0 --verbose 0
# Out:
# 2023-03-13 02:44:45  Experiment start!
# 2023-03-13 02:44:45  Namespace(F=1, agg2=0, agg_decay=0.001, agg_epochs=10, agg_function=1, agg_lr=0.001, agg_type='att', att_decay=0.0001, att_lr=0.001, batch_size=128, beta=1, cluster='deep', cuda=True, dataset='rt', debug=0, density=0.2, devices='gpu', dimension=32, dir='../Dataset/mnist', dropout=0.1, epoch=1500, ex='performance', external_dim=64, hidden_dims=[64, 64, 100], input_dim=128, interaction='NeuCF', lamda=1, latent_dim=10, log_interval=100, lr=0.0001, n_classes=10, n_clusters=10, n_jobs=1, node2vec=0, node2vec_batchsize=32, node2vec_dim=128, node2vec_epochs=20, node2vec_length=8, node2vec_walk=15, node2vec_windows=3, num_layers=2, order=2, part_iter=20, part_type=5, path='./datasets/data/WSDREAM/', pre_epoch=1000, pretrain=True, processed=0, random_state=2022, record=0, retrain=0, rounds=1, save_model=1, slice=1, slice_decay=0.001, slice_epochs=100, slice_lr=0.001, slices=5, verbose=0, wd=0.0005)
# 22 23 27 33 33 35 50 37 45 34
# ...
